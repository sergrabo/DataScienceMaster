# %% [markdown]
# A partir del código siguiente se pide

# %%
import math

class Shape(object):
    """A generic shape object."""
    
    def area(self):
        """Return area of the shape."""
        pass
    
    def perimeter(self):
        """Return perimeter of the shape."""
        pass

# %% [markdown]
# Implementar las clases `Square`, `Rectangle` y  `Circle`, sobreescribiendo los métodos `area` y `perimeter` para que muestren los resultados correctos

# %%
class Square(Shape):
    
    def __init__(self,b):
        """Build the square"""
        self.b=b
    
    def area(self):
        """Return area of the square."""
        return self.b * self.b
    
    def perimeter(self):
        """Return perimeter of the square."""
        return 4 * self.b
    
class Rectangle(Shape):
    
    def __init__(self,b,h):
        """Build the rectangle"""
        self.b=b
        self.h=h
    
    def area(self):
        """Return area of the rectangle."""
        return self.b * self.h
    
    def perimeter(self):
        """Return perimeter of the rectangle."""
        return 2 * self.b + 2 * self.h

class Circle(Shape):
    
    def __init__(self,r):
        """Build the circle"""
        self.r = r
    
    def area(self):
        """Return area of the circle."""
        return math.pi * self.r * self.r
    
    def perimeter(self):
        """Return perimeter of the circle."""
        return 2 * math.pi * self.r
s=Square(4)
r=Rectangle(2,3)
c=Circle(2)

print(s.area())
print(r.area())
print(c.area())
print("\n")
print(s.perimeter())
print(r.perimeter())
print(c.perimeter())
# Out:
# 16
# 6
# 12.566370614359172
#
#
# 16
# 10
# 12.566370614359172

# %% [markdown]
# Implementar las operaciones de suma, resta, y multiplicación, suponiendo que la suma, resta y multiplicación solo se puede realizar entre objetos del mismo tipo, y que la operación se realiza sobre sus dimensiones (es decir, la suma de dos círculos se realiza sumando sus radios de su circunferencia.

# %%
import math

class Shape(object):
    """A generic shape object."""
    
    def area(self):
        """Return area of the shape."""
        pass
    
    def perimeter(self):
        """Return perimeter of the shape."""
        pass
            
    
    
class Square(Shape):
    
    def __init__(self,b):
        """Build the square"""
        self.b=b
    
    def area(self):
        """Return area of the square."""
        return self.b * self.b
    
    def perimeter(self):
        """Return perimeter of the square."""
        return 4 * self.b
    
    def Add(self, Shape2):
        """Suma los parámetros de dos cuadrados."""
        if type(self) != type(Shape2): #Comprobación de que sean la misma forma
            print("ERROR: Las formas no coinciden")
        else:
            return self.b + Shape2.b
        
class Rectangle(Shape):
    
    def __init__(self,b,h):
        """Build the rectangle"""
        self.b=b
        self.h=h
    
    def area(self):
        """Return area of the rectangle."""
        return self.b * self.h
    
    def perimeter(self):
        """Return perimeter of the rectangle."""
        return 2 * self.b + 2 * self.h
    
    def Add(self, Shape2):
        """Suma los parámetros de dos rectángulos."""
        if type(self) != type(Shape2): #Comprobación de que sean la misma forma
            print("ERROR: Las formas no coinciden")
        else:
            return (self.b + Shape2.b, self.h + Shape2.h)

class Circle(Shape):
    
    def __init__(self,r):
        """Build the circle"""
        self.r = r
    
    def area(self):
        """Return area of the circle."""
        return math.pi * self.r * self.r
    
    def perimeter(self):
        """Return perimeter of the circle."""
        return 2 * math.pi * self.r
    
    def Add(self, Shape2):
        """Suma los parámetros de dos círculos."""
        if type(self) != type(Shape2): #Comprobación de que sean la misma forma
            print("ERROR: Las formas no coinciden")
        else:
            return self.r + Shape2.r
        
s=Square(4)
r=Rectangle(2,3)
c=Circle(2)

print(s.Add(s))
print(r.Add(r))
print(c.Add(c))

print("\n")

s.Add(c)
s.Add(r)
# Out:
# 8
# (4, 6)
# 4
#
#
# ERROR: Las formas no coinciden
# ERROR: Las formas no coinciden
