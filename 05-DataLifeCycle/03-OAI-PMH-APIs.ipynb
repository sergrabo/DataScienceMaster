# %% [markdown]
# # APIs + OAI-PMH
#
#
#
# ### Librerías necesarias para la práctica
#
# ```python
# import xml.etree.ElementTree as ET
# import requests
# import json
# ```

# %%
import xml.etree.ElementTree as ET
import requests
import json

# %% [markdown]
# ## Parte 1 - APIs - Swagger
# Vamos a utilizar el ejemplo de la tienda de mascotas en swagger:
# https://petstore.swagger.io

# %% [markdown]
# #### Ejercicio 1 - Lista 10 mascotas registradas

# %%
url = "https://petstore.swagger.io/v2/pet/findByStatus?status=available"
headers = {'Accept': 'application/json'}

r = requests.get(url, headers)
data = json.loads(r.text)

name = []

for i in range(len(data)):
    dicc = data[i]
    if dicc['name'] not in name:
        print('name:', dicc['name'], '| id:', dicc['id'])
        name.append(dicc['name'])
        if len(name) == 10:
            break
# Out:
# name: doggie | id: 9222968140497181785
# name: fish | id: 9222968140497181824
# name: Puff | id: 9222968140497182046
# name: doggie test | id: 234
# name: yuri pet | id: 1241
# name: horse | id: 9222968140497182277
# name: Llama | id: 991
# name: Sharky | id: 1640977066212
# name: laky | id: 65342
# name: test | id: 9222968140497180179

# %% [markdown]
# #### Ejercicio 2 - Registra una nueva mascota mascota

# %%
url = "https://petstore.swagger.io/v2/pet"
headers = {'Content-Type': 'application/json'}

pet = {
  "id": 15648,
  "category": {
    "id": 0,
    "name": "string"
  },
  "name": "Wolfie",
  "photoUrls": [
    "string"
  ],
  "tags": [
    {
      "id": 0,
      "name": "string"
    }
  ],
  "status": "available"
}


r = requests.post(url, json = pet, headers = headers)
r.status_code
# Out:
# 200

# %% [markdown]
# #### Ejercico 3 - Encuentra la mascota registrada con su ID

# %%
url = "https://petstore.swagger.io/v2/pet/15648"
headers = {'Accept': 'application/json'}

r = requests.get(url, headers)
data = json.loads(r.text)

print(data)
# Out:
# {'id': 15648, 'category': {'id': 0, 'name': 'string'}, 'name': 'Wolfie', 'photoUrls': ['string'], 'tags': [{'id': 0, 'name': 'string'}], 'status': 'available'}

# %% [markdown]
# ## Parte 2 - OAI-PMH
# La documentación del protocolo la podéis encontrar aquí:
#
# https://www.openarchives.org/OAI/openarchivesprotocol.html

# %% [markdown]
# ### Identify
#
# This verb is used to retrieve information about a repository. Some of the information returned is required as part of the OAI-PMH. Repositories may also employ the Identify verb to return additional descriptive information.

# %%
import xml.etree.ElementTree as ET
import requests

base_url = "https://zenodo.org/oai2d"
action = "?verb=Identify"
print("Request to: %s%s" % (base_url, action))
oai = requests.get(base_url + action) #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.fromstring(oai.text)
print(oai.text)
#Iterator para recorrer todos los elementos (incluso anidados)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)

#Findall para encontrar un elemento específico
namespaces = {'ns': 'http://www.openarchives.org/OAI/2.0/'} # add more as needed
elementos = xmlTree.findall('.//ns:baseURL',namespaces)
print(elementos) #Element
for e in elementos:
    print("BaseURL:", e.text)
# Out:
# Request to: https://zenodo.org/oai2d?verb=Identify
# <?xml version='1.0' encoding='UTF-8'?>
# <?xml-stylesheet type="text/xsl" href="/static/xsl/oai2.xsl"?>
# <OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">
#   <responseDate>2021-12-31T19:59:56Z</responseDate>
#   <request verb="Identify">https://zenodo.org/oai2d</request>
#   <Identify>
#     <repositoryName>Zenodo</repositoryName>
#     <baseURL>https://zenodo.org/oai2d</baseURL>
#     <protocolVersion>2.0</protocolVersion>
#     <adminEmail>info@zenodo.org</adminEmail>
#     <earliestDatestamp>2014-02-03T14:41:33Z</earliestDatestamp>
#     <deletedRecord>no</deletedRecord>
#     <granularity>YYYY-MM-DDThh:mm:ssZ</granularity>
#   </Identify>
# </OAI-PMH>
#
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2021-12-31T19:59:56Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}Identify:
#
# {http://www.openarchives.org/OAI/2.0/}repositoryName: Zenodo
# {http://www.openarchives.org/OAI/2.0/}baseURL: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}protocolVersion: 2.0
# {http://www.openarchives.org/OAI/2.0/}adminEmail: info@zenodo.org
# {http://www.openarchives.org/OAI/2.0/}earliestDatestamp: 2014-02-03T14:41:33Z
# {http://www.openarchives.org/OAI/2.0/}deletedRecord: no
# {http://www.openarchives.org/OAI/2.0/}granularity: YYYY-MM-DDThh:mm:ssZ
# [<Element '{http://www.openarchives.org/OAI/2.0/}baseURL' at 0x7ffa05a49728>]
# BaseURL: https://zenodo.org/oai2d

# %% [markdown]
# ### Listar tipos de metadatos
#
# ListMetadataFormats
#
# This verb is used to retrieve the metadata formats available from a repository. An optional argument restricts the request to the formats available for a specific item.

# %%
import xml.etree.ElementTree as ET
import requests

base_url = 'https://zenodo.org/oai2d'
action = '?verb=ListMetadataFormats'

oai = requests.get(base_url + action) #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.fromstring(oai.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2021-12-31T19:59:56Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListMetadataFormats:
#
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.openarchives.org/OAI/2.0/oai_dc/
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: dcat
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: https://www.w3.org/ns/dcat
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3

# %% [markdown]
# Podemos capturar sólo la información relevante

# %%
iterator = xmlTree.iter()
for elem in iterator:
    if (elem.tag == '{http://www.openarchives.org/OAI/2.0/}metadataPrefix') or (elem.tag == '{http://www.openarchives.org/OAI/2.0/}schema'):
        print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: dcat
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd

# %% [markdown]
# O de forma más "elegante"

# %%
for e in xmlTree.findall('.//{http://www.openarchives.org/OAI/2.0/}metadataFormat'):
    metadataPrefix = e.find('{http://www.openarchives.org/OAI/2.0/}metadataPrefix').text
    schema = e.find('{http://www.openarchives.org/OAI/2.0/}schema').text
    print(metadataPrefix, ':', schema)
# Out:
# marcxml : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# oai_datacite4 : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_dc : http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# dcat : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_datacite : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# marc21 : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# datacite : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# datacite4 : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd

# %% [markdown]
# Podemos describir el último schema

# %%
oai_datacite = requests.get('http://schema.datacite.org/meta/kernel-4.1/metadata.xsd') #Peticion al servidor
print(oai_datacite.text)

#Para crear el arbol XML
xmlTree = ET.fromstring(oai_datacite.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- Revision history
#   2010-08-26 Complete revision according to new common specification by the metadata work group after review. AJH, DTIC
#   2010-11-17 Revised to current state of kernel review, FZ, TIB
#   2011-01-17 Complete revsion after community review. FZ, TIB
#   2011-03-17 Release of v2.1: added a namespace; mandatory properties got minLength; changes in the definitions of relationTypes IsDocumentedBy/Documents and isCompiledBy/Compiles; changes type of property "Date" from xs:date to xs:string. FZ, TIB
#   2011-06-27 v2.2: namespace: kernel-2.2, additions to controlled lists "resourceType", "contributorType", "relatedIdentifierType", and "descriptionType". Removal of intermediate include-files.
#   2013-07-24 v3.0: namespace: kernel-3.0; delete LastMetadataUpdate & MetadateVersionNumber; additions to controlled lists "contributorType", "dateType", "descriptionType", "relationType", "relatedIdentifierType" & "resourceType"; deletion of "StartDate" & "EndDate" from list "dateType" and "Film" from "resourceType";  allow arbitrary order of elements; allow optional wrapper elements to be empty; include xml:lang attribute for title, subject & description; include attribute schemeURI for nameIdentifier of creator, contributor & subject; added new attributes "relatedMetadataScheme", "schemeURI" & "schemeType" to relatedIdentifier; included new property "geoLocation"
#   2014-08-20 v3.1: additions to controlled lists "relationType", contributorType" and "relatedIdentifierType"; introduction of new child element "affiliation" to "creator" and "contributor"
#   2016-09-19 v4.0: namespace: kernel-4.0; makes "resourceType" required field, added optional "givenName" and "familyName" to creator and contributor, added "funderReference", added "valueURI" for subject, added "geoLocationPolygon"
#   2017-10-23 v4.1: Addition of dateType value "Other", relationType values "Describes", "IsDescribedBy", "HasVersion", "IsVersionOf", "Requires", "IsRequiredBy", resourceType value "DataPaper", new subproperties "dateInformation", "inPolygonPoint", new attribute "nameType", optional attribute "resourceTypeGeneral" for relatedIdentifier
#   2018-09-08 v4.1.1 Make schema 4.1 backwards compatible to 4.0 by allowing geolocation elements in any order -->
# <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns="http://datacite.org/schema/kernel-4" targetNamespace="http://datacite.org/schema/kernel-4" elementFormDefault="qualified" xml:lang="EN">
#   <xs:import namespace="http://www.w3.org/XML/1998/namespace" schemaLocation="http://www.w3.org/2009/01/xml.xsd"/>
#   <xs:include schemaLocation="include/datacite-titleType-v4.xsd"/>
#   <xs:include schemaLocation="include/datacite-contributorType-v4.xsd"/>
#   <xs:include schemaLocation="include/datacite-dateType-v4.1.xsd"/>
#   <xs:include schemaLocation="include/datacite-resourceType-v4.1.xsd"/>
#   <xs:include schemaLocation="include/datacite-relationType-v4.1.xsd"/>
#   <xs:include schemaLocation="include/datacite-relatedIdentifierType-v4.xsd"/>
#   <xs:include schemaLocation="include/datacite-funderIdentifierType-v4.xsd"/>
#   <xs:include schemaLocation="include/datacite-descriptionType-v4.xsd"/>
#   <xs:include schemaLocation="include/datacite-nameType-v4.1.xsd"/>
#   <xs:element name="resource">
#     <xs:annotation>
#       <xs:documentation>
#         Root element of a single record. This wrapper element is for XML implementation only and is not defined in the DataCite DOI standard.
#         Note: This is the case for all wrapper elements within this schema.</xs:documentation>
#       <xs:documentation>No content in this wrapper element.</xs:documentation>
#     </xs:annotation>
#     <xs:complexType>
#       <xs:all>
#         <!--REQUIRED FIELDS-->
#         <xs:element name="identifier">
#           <xs:annotation>
#             <xs:documentation>A persistent identifier that identifies a resource.</xs:documentation>
#             <xs:documentation>Currently, only DOI is allowed.</xs:documentation>
#           </xs:annotation>
#           <xs:complexType>
#             <xs:simpleContent>
#               <xs:extension base="doiType">
#                 <xs:attribute name="identifierType" use="required" fixed="DOI"/>
#               </xs:extension>
#             </xs:simpleContent>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="creators">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="creator" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>The main researchers involved working on the data, or the authors of the publication in priority order. May be a corporate/institutional or personal name.</xs:documentation>
#                   <xs:documentation>Format: Family, Given.</xs:documentation>
#                   <xs:documentation>Personal names can be further specified using givenName and familyName.</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType>
#                   <xs:sequence>
#                     <xs:element name="creatorName">
#                       <xs:complexType>
#                         <xs:simpleContent>
#                           <xs:extension base="nonemptycontentStringType">
#                             <xs:attribute name="nameType" type="nameType" use="optional"/>
#                           </xs:extension>
#                         </xs:simpleContent>
#                       </xs:complexType>
#                     </xs:element>
#                     <xs:element name="givenName" minOccurs="0"/>
#                     <xs:element name="familyName" minOccurs="0"/>
#                     <xs:element name="nameIdentifier" minOccurs="0" maxOccurs="unbounded">
#                       <xs:complexType>
#                         <xs:simpleContent>
#                           <xs:extension base="nonemptycontentStringType">
#                             <xs:attribute name="nameIdentifierScheme" use="required"/>
#                             <xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
#                           </xs:extension>
#                         </xs:simpleContent>
#                       </xs:complexType>
#                     </xs:element>
#                     <xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
#                   </xs:sequence>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="titles">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="title" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>A name or title by which a resource is known.</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType>
#                   <xs:simpleContent>
#                     <xs:extension base="nonemptycontentStringType">
#                       <xs:attribute name="titleType" type="titleType" use="optional"/>
#                       <xs:attribute ref="xml:lang"/>
#                     </xs:extension>
#                   </xs:simpleContent>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="publisher">
#           <xs:annotation>
#             <xs:documentation>The name of the entity that holds, archives, publishes prints, distributes, releases, issues, or produces the resource. This property will be used to formulate the citation, so consider the prominence of the role.</xs:documentation>
#             <xs:documentation>In the case of datasets, "publish" is understood to mean making the data available to the community of researchers.</xs:documentation>
#           </xs:annotation>
#           <xs:simpleType>
#             <xs:restriction base="nonemptycontentStringType"/>
#           </xs:simpleType>
#         </xs:element>
#         <xs:element name="publicationYear">
#           <xs:annotation>
#             <xs:documentation>Year when the data is made publicly available. If an embargo period has been in effect, use the date when the embargo period ends.</xs:documentation>
#             <xs:documentation>In the case of datasets, "publish" is understood to mean making the data available on a specific date to the community of researchers. If there is no standard publication year value, use the date that would be preferred from a citation perspective.</xs:documentation>
#             <xs:documentation>YYYY</xs:documentation>
#           </xs:annotation>
#           <xs:simpleType>
#             <xs:restriction base="yearType"/>
#           </xs:simpleType>
#         </xs:element>
#         <xs:element name="resourceType">
#           <xs:annotation>
#             <xs:documentation>The type of a resource. You may enter an additional free text description.</xs:documentation>
#             <xs:documentation>The format is open, but the preferred format is a single term of some detail so that a pair can be formed with the sub-property.</xs:documentation>
#           </xs:annotation>
#           <xs:complexType>
#             <xs:simpleContent>
#               <xs:extension base="xs:string">
#                 <xs:attribute name="resourceTypeGeneral" type="resourceType" use="required"/>
#               </xs:extension>
#             </xs:simpleContent>
#           </xs:complexType>
#         </xs:element>
#         <!--OPTIONAL FIELDS-->
#         <xs:element name="subjects" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="subject" minOccurs="0" maxOccurs="unbounded">
#               <xs:annotation>
#                 <xs:documentation>Subject, keywords, classification codes, or key phrases describing the resource.</xs:documentation>
#               </xs:annotation>
#               <xs:complexType>
#                 <xs:simpleContent>
#                   <xs:extension base="xs:string">
#                     <xs:attribute name="subjectScheme" use="optional"/>
#                     <xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
#                     <xs:attribute name="valueURI" type="xs:anyURI" use="optional"/>
#                     <xs:attribute ref="xml:lang"/>
#                   </xs:extension>
#                 </xs:simpleContent>
#               </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="contributors" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="contributor" minOccurs="0" maxOccurs="unbounded">
#               <xs:annotation>
#                 <xs:documentation>The institution or person responsible for collecting, creating, or otherwise contributing to the developement of the dataset.</xs:documentation>
#                 <xs:documentation>The personal name format should be: Family, Given.</xs:documentation>
#               </xs:annotation>
#               <xs:complexType>
#                 <xs:sequence>
#                   <xs:element name="contributorName">
#                     <xs:complexType>
#                       <xs:simpleContent>
#                         <xs:extension base="nonemptycontentStringType">
#                           <xs:attribute name="nameType" type="nameType" use="optional"/>
#                         </xs:extension>
#                       </xs:simpleContent>
#                     </xs:complexType>
#                   </xs:element>
#                   <xs:element name="givenName" minOccurs="0"/>
#                   <xs:element name="familyName" minOccurs="0"/>
#                   <xs:element name="nameIdentifier" minOccurs="0" maxOccurs="unbounded">
#                     <xs:complexType>
#                       <xs:simpleContent>
#                         <xs:extension base="xs:string">
#                           <xs:attribute name="nameIdentifierScheme" use="required"/>
#                           <xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
#                         </xs:extension>
#                       </xs:simpleContent>
#                     </xs:complexType>
#                   </xs:element>
#                   <xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
#                 </xs:sequence>
#                 <xs:attribute name="contributorType" type="contributorType" use="required"/>
#               </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="dates" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="date" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>Different dates relevant to the work.</xs:documentation>
#                   <xs:documentation>YYYY,YYYY-MM-DD, YYYY-MM-DDThh:mm:ssTZD or any other format or level of granularity described in W3CDTF. Use RKMS-ISO8601 standard for depicting date ranges.</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType>
#                   <xs:simpleContent>
#                     <xs:extension base="xs:string">
#                       <xs:attribute name="dateType" type="dateType" use="required"/>
#                       <xs:attribute name="dateInformation" use="optional"/>
#                     </xs:extension>
#                   </xs:simpleContent>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="language" type="xs:language" minOccurs="0">
#           <xs:annotation>
#             <xs:documentation>Primary language of the resource. Allowed values are taken from  IETF BCP 47, ISO 639-1 language codes.</xs:documentation>
#           </xs:annotation>
#         </xs:element>
#         <xs:element name="alternateIdentifiers" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="alternateIdentifier" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>An identifier or identifiers other than the primary Identifier applied to the resource being registered. This may be any alphanumeric string which is unique within its domain of issue. May be used for local identifiers. AlternateIdentifier should be used for another identifier of the same instance (same location, same file).</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType>
#                   <xs:simpleContent>
#                     <xs:extension base="xs:string">
#                       <xs:attribute name="alternateIdentifierType" use="required"/>
#                     </xs:extension>
#                   </xs:simpleContent>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="relatedIdentifiers" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="relatedIdentifier" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>Identifiers of related resources. Use this property to indicate subsets of properties, as appropriate.</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType>
#                   <xs:simpleContent>
#                     <xs:extension base="xs:string">
#                       <xs:attribute name="resourceTypeGeneral" type="resourceType" use="optional"/>
#                       <xs:attribute name="relatedIdentifierType" type="relatedIdentifierType" use="required"/>
#                       <xs:attribute name="relationType" type="relationType" use="required"/>
#                       <xs:attribute name="relatedMetadataScheme" use="optional"/>
#                       <xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
#                       <xs:attribute name="schemeType" use="optional"/>
#                     </xs:extension>
#                   </xs:simpleContent>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="sizes" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="size" type="xs:string" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>Unstructures size information about the resource.</xs:documentation>
#                 </xs:annotation>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="formats" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="format" type="xs:string" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>Technical format of the resource.</xs:documentation>
#                   <xs:documentation>Use file extension or MIME type where possible.</xs:documentation>
#                 </xs:annotation>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="version" type="xs:string" minOccurs="0">
#           <xs:annotation>
#             <xs:documentation>Version number of the resource. If the primary resource has changed the version number increases.</xs:documentation>
#             <xs:documentation>Register a new identifier for a major version change. Individual stewards need to determine which are major vs. minor versions. May be used in conjunction with properties 11 and 12 (AlternateIdentifier and RelatedIdentifier) to indicate various information updates. May be used in conjunction with property 17 (Description) to indicate the nature and file/record range of version.</xs:documentation>
#           </xs:annotation>
#         </xs:element>
#         <xs:element name="rightsList" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="rights" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>Any rights information for this resource. Provide a rights management statement for the resource or reference a service providing such information. Include embargo information if applicable.
# Use the complete title of a license and include version information if applicable.</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType>
#                   <xs:simpleContent>
#                     <xs:extension base="xs:string">
#                       <xs:attribute name="rightsURI" type="xs:anyURI" use="optional"/>
#                       <xs:attribute ref="xml:lang"/>
#                     </xs:extension>
#                   </xs:simpleContent>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="descriptions" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="description" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>All additional information that does not fit in any of the other categories. May be used for technical information. It is a best practice to supply a description.</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType mixed="true">
#                   <xs:choice>
#                     <xs:element name="br" minOccurs="0" maxOccurs="unbounded">
#                       <xs:simpleType>
#                         <xs:restriction base="xs:string">
#                           <xs:length value="0"/>
#                         </xs:restriction>
#                       </xs:simpleType>
#                     </xs:element>
#                   </xs:choice>
#                   <xs:attribute name="descriptionType" type="descriptionType" use="required"/>
#                   <xs:attribute ref="xml:lang"/>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="geoLocations" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="geoLocation" minOccurs="0" maxOccurs="unbounded">
#                 <xs:complexType>
#                   <xs:choice maxOccurs="unbounded">
#                     <xs:element name="geoLocationPlace" minOccurs="0">
#                       <xs:annotation>
#                         <xs:documentation>Spatial region or named place where the data was gathered or about which the data is focused.</xs:documentation>
#                       </xs:annotation>
#                     </xs:element>
#                     <xs:element name="geoLocationPoint" type="point" minOccurs="0">
#                       <xs:annotation>
#                         <xs:documentation>A point contains a single latitude-longitude pair.</xs:documentation>
#                       </xs:annotation>
#                     </xs:element>
#                     <xs:element name="geoLocationBox" type="box" minOccurs="0">
#                       <xs:annotation>
#                         <xs:documentation>A box contains two white space separated latitude-longitude pairs, with each pair separated by whitespace. The first pair is the lower corner, the second is the upper corner.</xs:documentation>
#                       </xs:annotation>
#                     </xs:element>
#                     <xs:element name="geoLocationPolygon" minOccurs="0" maxOccurs="unbounded">
#                       <xs:annotation>
#                         <xs:documentation>A drawn polygon area, defined by a set of points and lines connecting the points in a closed chain.</xs:documentation>
#                       </xs:annotation>
#                       <xs:complexType>
#                         <xs:sequence>
#                           <xs:element name="polygonPoint" type="point" minOccurs="4" maxOccurs="unbounded"/>
#                           <xs:element name="inPolygonPoint" type="point" minOccurs="0" maxOccurs="1"/>
#                         </xs:sequence>
#                       </xs:complexType>
#                     </xs:element>
#                   </xs:choice>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#         <xs:element name="fundingReferences" minOccurs="0">
#           <xs:complexType>
#             <xs:sequence>
#               <xs:element name="fundingReference" minOccurs="0" maxOccurs="unbounded">
#                 <xs:annotation>
#                   <xs:documentation>Information about financial support (funding) for the resource being registered.</xs:documentation>
#                 </xs:annotation>
#                 <xs:complexType>
#                   <xs:all>
#                     <xs:element name="funderName" minOccurs="1" maxOccurs="1">
#                       <xs:annotation>
#                         <xs:documentation>Name of the funding provider.</xs:documentation>
#                       </xs:annotation>
#                       <xs:simpleType>
#                         <xs:restriction base="nonemptycontentStringType"/>
#                       </xs:simpleType>
#                     </xs:element>
#                     <xs:element name="funderIdentifier" minOccurs="0">
#                       <xs:annotation>
#                         <xs:documentation>Uniquely identifies a funding entity, according to various types.</xs:documentation>
#                       </xs:annotation>
#                       <xs:complexType>
#                         <xs:simpleContent>
#                           <xs:extension base="xs:string">
#                             <xs:attribute name="funderIdentifierType" type="funderIdentifierType" use="required"/>
#                           </xs:extension>
#                         </xs:simpleContent>
#                       </xs:complexType>
#                     </xs:element>
#                     <xs:element name="awardNumber" minOccurs="0">
#                       <xs:annotation>
#                         <xs:documentation>The code assigned by the funder to a sponsored award (grant).</xs:documentation>
#                       </xs:annotation>
#                       <xs:complexType>
#                         <xs:simpleContent>
#                           <xs:extension base="xs:string">
#                             <xs:attribute name="awardURI" type="xs:anyURI" use="optional"/>
#                           </xs:extension>
#                         </xs:simpleContent>
#                       </xs:complexType>
#                     </xs:element>
#                     <xs:element name="awardTitle" minOccurs="0">
#                       <xs:annotation>
#                         <xs:documentation>The human readable title of the award (grant).</xs:documentation>
#                       </xs:annotation>
#                       <xs:simpleType>
#                         <xs:restriction base="nonemptycontentStringType"/>
#                       </xs:simpleType>
#                     </xs:element>
#                   </xs:all>
#                 </xs:complexType>
#               </xs:element>
#             </xs:sequence>
#           </xs:complexType>
#         </xs:element>
#       </xs:all>
#     </xs:complexType>
#   </xs:element>
#   <!-- TYPE DECLARATIONS -->
#   <!-- defines the value for a DOI"  -->
#   <xs:simpleType name="doiType">
#     <xs:restriction base="xs:token">
#       <xs:pattern value="10\..+/.+"/>
#     </xs:restriction>
#   </xs:simpleType>
#   <!-- defines value for mandatory fields -->
#   <xs:simpleType name="nonemptycontentStringType">
#     <xs:restriction base="xs:string">
#       <xs:minLength value="1"/>
#     </xs:restriction>
#   </xs:simpleType>
#   <xs:attributeGroup name="nameId">
#     <xs:attribute name="nameIdentifier" type="xs:string" use="optional"/>
#     <xs:attribute name="nameIdentifierScheme" type="xs:string" use="optional"/>
#   </xs:attributeGroup>
#   <!-- defines the value for a year -->
#   <xs:simpleType name="yearType">
#     <xs:restriction base="xs:token">
#       <xs:pattern value="[\d]{4}"/>
#     </xs:restriction>
#   </xs:simpleType>
#   <!-- definitions for geoLocation -->
#   <xs:complexType name="point">
#     <xs:all>
#       <xs:element name="pointLongitude" type="longitudeType" minOccurs="1"/>
#       <xs:element name="pointLatitude" type="latitudeType" minOccurs="1"/>
#     </xs:all>
#   </xs:complexType>
#   <xs:complexType name="box">
#     <xs:all>
#       <xs:element name="westBoundLongitude" type="longitudeType" minOccurs="1"/>
#       <xs:element name="eastBoundLongitude" type="longitudeType" minOccurs="1"/>
#       <xs:element name="southBoundLatitude" type="latitudeType" minOccurs="1"/>
#       <xs:element name="northBoundLatitude" type="latitudeType" minOccurs="1"/>
#     </xs:all>
#   </xs:complexType>
#   <xs:simpleType name="longitudeType">
#     <xs:restriction base="xs:float">
#       <xs:minInclusive value="-180"/>
#       <xs:maxInclusive value="180"/>
#     </xs:restriction>
#   </xs:simpleType>
#   <xs:simpleType name="latitudeType">
#     <xs:restriction base="xs:float">
#       <xs:minInclusive value="-90"/>
#       <xs:maxInclusive value="90"/>
#     </xs:restriction>
#   </xs:simpleType>
# </xs:schema>
#
# {http://www.w3.org/2001/XMLSchema}schema
# {http://www.w3.org/2001/XMLSchema}import
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}all
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}choice
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}length
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}choice
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}all
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}attributeGroup
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}all
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}all
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minInclusive
# {http://www.w3.org/2001/XMLSchema}maxInclusive
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minInclusive
# {http://www.w3.org/2001/XMLSchema}maxInclusive

# %% [markdown]
# Si analizamos la descripción del estándar, vemos que las etiquetas de los metadatos están almacenados en la etiqueta "element", en el atributo "name". Podemos obetener un listado de lo que esperamos encontrar

# %%
namespaces = {'xs' : 'http://www.w3.org/2001/XMLSchema'}
for tags in xmlTree.findall('.//xs:element',namespaces):
    print ('Metadato: ',tags.attrib['name'])
# Out:
# Metadato:  resource
# Metadato:  identifier
# Metadato:  creators
# Metadato:  creator
# Metadato:  creatorName
# Metadato:  givenName
# Metadato:  familyName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  titles
# Metadato:  title
# Metadato:  publisher
# Metadato:  publicationYear
# Metadato:  resourceType
# Metadato:  subjects
# Metadato:  subject
# Metadato:  contributors
# Metadato:  contributor
# Metadato:  contributorName
# Metadato:  givenName
# Metadato:  familyName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  dates
# Metadato:  date
# Metadato:  language
# Metadato:  alternateIdentifiers
# Metadato:  alternateIdentifier
# Metadato:  relatedIdentifiers
# Metadato:  relatedIdentifier
# Metadato:  sizes
# Metadato:  size
# Metadato:  formats
# Metadato:  format
# Metadato:  version
# Metadato:  rightsList
# Metadato:  rights
# Metadato:  descriptions
# Metadato:  description
# Metadato:  br
# Metadato:  geoLocations
# Metadato:  geoLocation
# Metadato:  geoLocationPlace
# Metadato:  geoLocationPoint
# Metadato:  geoLocationBox
# Metadato:  geoLocationPolygon
# Metadato:  polygonPoint
# Metadato:  inPolygonPoint
# Metadato:  fundingReferences
# Metadato:  fundingReference
# Metadato:  funderName
# Metadato:  funderIdentifier
# Metadato:  awardNumber
# Metadato:  awardTitle
# Metadato:  pointLongitude
# Metadato:  pointLatitude
# Metadato:  westBoundLongitude
# Metadato:  eastBoundLongitude
# Metadato:  southBoundLatitude
# Metadato:  northBoundLatitude

# %% [markdown]
# ### ListIdentifiers
#
# This verb is an abbreviated form of ListRecords, retrieving only headers rather than records. Optional arguments permit selective harvesting of headers based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted.
#
# Devuelve la cabecera de los registros, para conocer la información esencial.
#
# Necesita el prefijo del formato de metadatos

# %%
#prefijo: oai_datacite4
base_url = 'https://zenodo.org/oai2d'
action = '?verb=ListIdentifiers'
params =  '&metadataPrefix=oai_datacite4'

oai = requests.get(base_url + action + params)
xmlTree = ET.fromstring(oai.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text) #Identifiers are really important because they are used to ask more information
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2021-12-31T19:59:57Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListIdentifiers:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3342065
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-07-19T07:05:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1228465
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-18T00:07:20Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1227825
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:05:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1227813
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:05:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1227809
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:04:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1227807
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:04:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1227805
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:04:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1227795
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:03:43Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1227793
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:03:34Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1226501
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-04-21T11:30:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1221856
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T11:22:43Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1221854
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T11:22:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1221148
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-04-19T13:16:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1221088
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-21T23:52:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1221086
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-21T23:52:32Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1221084
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-21T23:52:28Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1216701
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T05:00:43Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1216516
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-22T01:59:50Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1216510
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-22T01:59:37Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1212943
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T10:09:32Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1209778
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T06:10:40Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1207176
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T08:24:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1207174
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T08:23:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1207172
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T08:23:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1207168
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T08:23:38Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1207166
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T08:23:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1207164
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T08:23:23Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206902
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:24:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206900
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:24:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206896
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:24:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206890
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:23:41Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206888
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:23:38Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206886
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:23:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206882
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:23:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206880
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:22:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206876
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:22:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206860
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:21:05Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206854
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:20:53Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206852
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:20:50Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206850
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:20:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206848
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:20:43Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206846
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:20:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206844
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:20:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206838
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:19:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206832
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:19:20Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206830
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:19:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206826
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:19:08Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206822
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:19:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206762
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:13:42Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206756
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:13:14Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206752
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:13:07Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206744
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:12:13Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206734
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:11:54Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206728
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:10:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206718
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:09:46Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206702
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:08:18Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206690
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-24T08:36:00Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206682
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:05:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206672
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:04:25Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206666
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:04:18Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206664
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:04:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206650
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:01:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206648
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T14:01:54Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206634
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:59:32Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206630
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:59:23Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206628
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:59:19Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206624
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:58:33Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206606
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:57:08Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206602
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:56:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206584
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:55:27Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206578
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:55:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206566
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:53:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206564
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:53:53Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206558
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:53:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206556
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:53:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206550
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:52:21Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206548
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:52:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206538
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T23:38:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206530
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T23:38:16Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206526
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T23:38:00Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206520
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:49:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206516
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206512
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206508
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:41Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206506
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206504
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206502
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:32Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206500
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:23Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206498
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:20Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206496
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:48:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206492
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:47:32Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206486
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:47:18Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206484
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:47:14Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206452
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:33:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206448
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:33:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206446
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:33:14Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206432
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-06-23T18:37:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206420
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:30:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1206408
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-24T13:30:03Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:1205013
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2018-03-21T15:37:18Z
# {http://www.openarchives.org/OAI/2.0/}resumptionToken: .eJwdjc0KgkAYAN_lO0vsbv4leDCsg5Sk2WpeZNEvW1xRVCgS3z1rjjOHmWFErMAhG9Oiuy1jFrWJZdom1WAsh06pQq4Z_OxI8ywwotRo4paTO6v33p-k4OEhPSelflXxJ0_UDZvwyf04OPGecRJkUeS6oEEvagSHadC8xFCP4MzQ4iQqMYnLgA_5XjedkMVPlHJCHZblC5YpMYM.Yc9hPQ.pMxoqGFqjXYYUPlBX0dpdkvBJLQ

# %% [markdown]
# ### ListRecords
#
# Listar los registros
#
# This verb is used to harvest records from a repository. Optional arguments permit selective harvesting of records based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted. No metadata will be present for records with deleted status.

# %%
import xml.etree.ElementTree as ET
import requests

base_url = 'https://zenodo.org/oai2d'
action = '?verb=ListRecords'
params =  '&metadataPrefix=oai_datacite4'
oai = requests.get(base_url + action + params)

xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2021-12-31T19:59:58Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3342065
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-07-19T07:05:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.3342065
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# IMARC Services
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Exterior Sheathing Market: Global Industry Overview, Sales Revenue, Demand and Forecast by 2024
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# global exterior sheathing market, exterior sheathing market share, exterior sheathing market size, exterior sheathing market trends, exterior sheathing market growth, exterior sheathing market report, exterior sheathing market forecast, exterior sheathing
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-07-19
# {http://datacite.org/schema/kernel-4}resourceType
# Presentation
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.3342064
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# <p><strong>Get more information about the market: </strong><a href="https://www.imarcgroup.com/exterior-sheathing-market">https://www.imarcgroup.com/exterior-sheathing-market</a></p>
#
# <p>The global exterior sheathing market size reached US$ 6.6 Billion in 2018. Exterior sheathing is used in roofs, walls and floor assemblies to give a layer of protection against outside elements and to prevent wind and water from entering.</p>
#
# <p><strong>Want more information about this market? Request a free report sample: </strong><a href="https://www.imarcgroup.com/exterior-sheathing-market/requestsample">https://www.imarcgroup.com/exterior-sheathing-market/requestsample</a></p>
#
# <p><strong>For India market research reports, visit:</strong> <a href="http://www.marketresearchindia.co.in">http://www.marketresearchindia.co.in</a></p>
#
# <p>Contact Us</p>
#
# <p>IMARC Group<br>
# James Smith<br>
# Email: Sales@imarcgroup.com<br>
# Tel No:(D) +91 120 433 0800 | https://www.imarcgroup.com<br>
# Americas :- +1 631 791 1145 | Africa and Europe :- +44-702-409-7331<br>
# Linkedin: https://www.linkedin.com/company/imarc-group</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1228465
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-18T00:07:20Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1228465
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Abrahão, Felipe S.
# {http://datacite.org/schema/kernel-4}givenName
# Felipe S.
# {http://datacite.org/schema/kernel-4}familyName
# Abrahão
# {http://datacite.org/schema/kernel-4}affiliation
# National Laboratory for Scientific Computing (LNCC)
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Wehmuth, Klaus
# {http://datacite.org/schema/kernel-4}givenName
# Klaus
# {http://datacite.org/schema/kernel-4}familyName
# Wehmuth
# {http://datacite.org/schema/kernel-4}affiliation
# National Laboratory for Scientific Computing (LNCC)
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ziviani, Artur
# {http://datacite.org/schema/kernel-4}givenName
# Artur
# {http://datacite.org/schema/kernel-4}familyName
# Ziviani
# {http://datacite.org/schema/kernel-4}affiliation
# National Laboratory for Scientific Computing (LNCC)
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Felipe-Klaus-Artur's second paper
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-02-17
# {http://datacite.org/schema/kernel-4}resourceType
# Working paper
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1174535
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Closed Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# <p>Draft on the second paper about the extension of the first paper&#39;s results to SIS scale-free networks.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1227825
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-24T05:05:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1227825
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Amaoka, Kunio
# {http://datacite.org/schema/kernel-4}givenName
# Kunio
# {http://datacite.org/schema/kernel-4}familyName
# Amaoka
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ho, Hsuan-Ching
# {http://datacite.org/schema/kernel-4}givenName
# Hsuan-Ching
# {http://datacite.org/schema/kernel-4}familyName
# Ho
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 17 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-4}subject
# Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject
# Bothidae
# {http://datacite.org/schema/kernel-4}subject
# Engyprosopon
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-24
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFABFF8230E1F9C1FB1D987D
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4E624401FFB2FF9C3076FFABFFB29F53
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1227824
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 17. Engyprosopon parvipectorale sp. nov. Blind side, same specimens as those in Figure 15.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1227813
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-24T05:05:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1227813
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Amaoka, Kunio
# {http://datacite.org/schema/kernel-4}givenName
# Kunio
# {http://datacite.org/schema/kernel-4}familyName
# Amaoka
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ho, Hsuan-Ching
# {http://datacite.org/schema/kernel-4}givenName
# Hsuan-Ching
# {http://datacite.org/schema/kernel-4}familyName
# Ho
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 11 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-4}subject
# Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject
# Bothidae
# {http://datacite.org/schema/kernel-4}subject
# Engyprosopon
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-24
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFA2FF8F30E1FB96FF439EA7
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4E624401FFB2FF9C3076FFABFFB29F53
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1227812
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 11. Engyprosopon brevifrontale sp. nov. A. Rostral and orbital spines on ocular side, B. rostral spine on blind side, C. gill rakers on first arch, from NMMB-P25746, paratype.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1227809
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-24T05:04:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1227809
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Amaoka, Kunio
# {http://datacite.org/schema/kernel-4}givenName
# Kunio
# {http://datacite.org/schema/kernel-4}familyName
# Amaoka
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ho, Hsuan-Ching
# {http://datacite.org/schema/kernel-4}givenName
# Hsuan-Ching
# {http://datacite.org/schema/kernel-4}familyName
# Ho
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 9 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-4}subject
# Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject
# Bothidae
# {http://datacite.org/schema/kernel-4}subject
# Engyprosopon
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-24
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFBEFF9330E1F8ABFA259887
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4E624401FFB2FF9C3076FFABFFB29F53
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1227808
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 9. Engyprosopon maldivense (Regan, 1908). Blind side, same specimens as those in Figure 8.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1227807
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-24T05:04:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1227807
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Amaoka, Kunio
# {http://datacite.org/schema/kernel-4}givenName
# Kunio
# {http://datacite.org/schema/kernel-4}familyName
# Amaoka
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ho, Hsuan-Ching
# {http://datacite.org/schema/kernel-4}givenName
# Hsuan-Ching
# {http://datacite.org/schema/kernel-4}familyName
# Ho
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 8 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-4}subject
# Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject
# Bothidae
# {http://datacite.org/schema/kernel-4}subject
# Engyprosopon
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-24
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFB3FF9E30E1F8C7FA2E9C61
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFBEFF9330E1F8ABFA259887
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4E624401FFB2FF9C3076FFABFFB29F53
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1227806
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 8. Engyprosopon maldivense (Regan, 1908). Ocular side, A. NMMB-P22226, male, 121.3 mm SL. B. NMMB- P22238, female, 102.3 mm SL.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1227805
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-24T05:04:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1227805
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Amaoka, Kunio
# {http://datacite.org/schema/kernel-4}givenName
# Kunio
# {http://datacite.org/schema/kernel-4}familyName
# Amaoka
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ho, Hsuan-Ching
# {http://datacite.org/schema/kernel-4}givenName
# Hsuan-Ching
# {http://datacite.org/schema/kernel-4}familyName
# Ho
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 7 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-4}subject
# Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject
# Bothidae
# {http://datacite.org/schema/kernel-4}subject
# Engyprosopon
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-24
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFB8FF9030E1FD57FA3E99FE
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4E624401FFB2FF9C3076FFABFFB29F53
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1227804
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 7. Engyprosopon mogkii (Bleeker, 1854). A. Scales on ocular side, B. Gill rakers on first arch, from ASIZP 63578.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1227795
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-24T05:03:43Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1227795
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Amaoka, Kunio
# {http://datacite.org/schema/kernel-4}givenName
# Kunio
# {http://datacite.org/schema/kernel-4}familyName
# Amaoka
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ho, Hsuan-Ching
# {http://datacite.org/schema/kernel-4}givenName
# Hsuan-Ching
# {http://datacite.org/schema/kernel-4}familyName
# Ho
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 2 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-4}subject
# Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject
# Bothidae
# {http://datacite.org/schema/kernel-4}subject
# Engyprosopon
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-24
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFB6FF9B30E1FC09FEF59B0B
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4E624401FFB2FF9C3076FFABFFB29F53
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1227794
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 2. Engyprosopon grandisquama (Temminck &amp; Schlegel, 1846). Ocular side, A. NMMB-P22235, male, 74.7 mm SL. B. NMMB-P22302, female, 72.6 mm SL.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1227793
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-24T05:03:34Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1227793
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Amaoka, Kunio
# {http://datacite.org/schema/kernel-4}givenName
# Kunio
# {http://datacite.org/schema/kernel-4}familyName
# Amaoka
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ho, Hsuan-Ching
# {http://datacite.org/schema/kernel-4}givenName
# Hsuan-Ching
# {http://datacite.org/schema/kernel-4}familyName
# Ho
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 1. Engyprosopon xystrias Hubbs, 1915. NMMB-P22216 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-4}subject
# Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject
# Bothidae
# {http://datacite.org/schema/kernel-4}subject
# Engyprosopon
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-24
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/B25B3C79FFB0FF9830E1FC29FEB89C0F
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4E624401FFB2FF9C3076FFABFFB29F53
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4413.3.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1227791
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1227792
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 1. Engyprosopon xystrias Hubbs, 1915. NMMB-P22216, male, 88.7 mm SL. A. ocular side, B. blind side.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1226501
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-04-21T11:30:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1226501
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# David Prötzel
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Miguel Vences
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Oliver Hawlitschek
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Mark D. Scherz
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Fanomezana M. Ratsoavina
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Frank Glaw
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Figure 7 in Endangered beauties: micro-CT cranial osteology, molecular genetics and external morphology reveal three new species of chameleons in the Calumma boettgeri complex (Squamata: Chamaeleonidae)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Chordata
# {http://datacite.org/schema/kernel-4}subject
# Reptilia
# {http://datacite.org/schema/kernel-4}subject
# Squamata
# {http://datacite.org/schema/kernel-4}subject
# Chamaeleonidae
# {http://datacite.org/schema/kernel-4}subject
# Calumma
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-09
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/03B487F21643FFD639FDFD02FA6904BA
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.1093/zoolinnean/zlx112
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:FF8DFF8A164DFFC53A42FFABFFE90568
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1226487
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1226500
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# Figure 7. Calumma juliae sp. nov. coloration in life during day.A, female holotype ZSM 143/2016 relaxed.B, juvenile ZSM254/2016 relaxed. C, D, portrait of female ZSM 254/2016 with stress pattern (C) and slightly displaying (D).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1221856
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-23T11:22:43Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1221856
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Zheng, Li-Hao
# {http://datacite.org/schema/kernel-4}givenName
# Li-Hao
# {http://datacite.org/schema/kernel-4}familyName
# Zheng
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Chen, Jun
# {http://datacite.org/schema/kernel-4}givenName
# Jun
# {http://datacite.org/schema/kernel-4}familyName
# Chen
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 4 in Taxonomic study on the genus Fissicepheus (Acari: Oribatida: Otocepheidae) from China
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Arthropoda
# {http://datacite.org/schema/kernel-4}subject
# Arachnida
# {http://datacite.org/schema/kernel-4}subject
# Sarcoptiformes
# {http://datacite.org/schema/kernel-4}subject
# Otocepheidae
# {http://datacite.org/schema/kernel-4}subject
# Fissicepheus
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-18
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/C9693B420235FFB2FF1D960F9D5AF84A
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4410.3.7
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:3550433A0230FFB7FF8A976A9E0AFFBB
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1221848
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4410.3.7
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1221848
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1221855
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 4. Fissicepheus (Fissicepheus) confragosus n. sp.: a, leg I, antiaxial view; b, leg II, antiaxial view; c, leg III, antiaxial view; d, leg IV, antiaxial view. Scal bars: a–d=50µm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1221854
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-23T11:22:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1221854
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Zheng, Li-Hao
# {http://datacite.org/schema/kernel-4}givenName
# Li-Hao
# {http://datacite.org/schema/kernel-4}familyName
# Zheng
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Chen, Jun
# {http://datacite.org/schema/kernel-4}givenName
# Jun
# {http://datacite.org/schema/kernel-4}familyName
# Chen
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 3 in Taxonomic study on the genus Fissicepheus (Acari: Oribatida: Otocepheidae) from China
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Arthropoda
# {http://datacite.org/schema/kernel-4}subject
# Arachnida
# {http://datacite.org/schema/kernel-4}subject
# Sarcoptiformes
# {http://datacite.org/schema/kernel-4}subject
# Otocepheidae
# {http://datacite.org/schema/kernel-4}subject
# Fissicepheus
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-18
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/C9693B420235FFB2FF1D960F9D5AF84A
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4410.3.7
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:3550433A0230FFB7FF8A976A9E0AFFBB
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1221848
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4410.3.7
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1221848
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1221853
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 3. Fissicepheus (Fissicepheus) confragosus n. sp.: a, dorsal aspect (legs removed); b, lateral view of notogaster, with trochanters and femora of legs III–IV; c, lateral view of prodorsum; d, ventral aspect (legs removed).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1221148
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-04-19T13:16:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1221148
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Huang, Mian
# {http://datacite.org/schema/kernel-4}givenName
# Mian
# {http://datacite.org/schema/kernel-4}familyName
# Huang
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Huang, Yong
# {http://datacite.org/schema/kernel-4}givenName
# Yong
# {http://datacite.org/schema/kernel-4}familyName
# Huang
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 1 in Two new species of Comesomatidae (Nematoda) from the East China Sea
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Nematoda
# {http://datacite.org/schema/kernel-4}subject
# Chromadorea
# {http://datacite.org/schema/kernel-4}subject
# Desmodorida
# {http://datacite.org/schema/kernel-4}subject
# Comesomatidae
# {http://datacite.org/schema/kernel-4}subject
# Paracomesoma
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-04-12
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/A7472C7698119010FF5EFC73FC274D35
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4407.4.9
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:5B7E540E98109014FFC9FFF5FFC14E68
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1221146
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1221147
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 1. Paracomesoma zhangi sp. nov. (A) lateral view of male posterior end, showing spicules, gubernaculum and precloacal supplements; (B) lateral view of male anterior end, showing buccal cavity, cephalic setae and amphideal fovea; (C) lateral view of male pharyngeal region, showing secretory-excretory system; (D) lateral view of cloacal region, showing spicules, gubernaculum, precloacal seta and precloacal supplements.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1221088
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-06-21T23:52:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1221088
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Shavrin, Alexey V.
# {http://datacite.org/schema/kernel-4}givenName
# Alexey V.
# {http://datacite.org/schema/kernel-4}familyName
# Shavrin
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# ...
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Jałoszyński, Paweł
# {http://datacite.org/schema/kernel-4}givenName
# Paweł
# {http://datacite.org/schema/kernel-4}familyName
# Jałoszyński
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURES 7–11 in A new species of Clidicus with asymmetrical parameres (Coleoptera, Staphylinidae, Scydmaeninae)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Arthropoda
# {http://datacite.org/schema/kernel-4}subject
# Insecta
# {http://datacite.org/schema/kernel-4}subject
# Coleoptera
# {http://datacite.org/schema/kernel-4}subject
# Staphylinidae
# {http://datacite.org/schema/kernel-4}subject
# Clidicus
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-03-20
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/BD0B8784FFBB6903BCFEF8B5793DFE71
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4399.1.12
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:4132FFFCFFBB6907BC69FFB37D02FFB5
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1206426
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4399.1.12
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1206426
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1206431
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURES 7–11. Clidicus asymmetricus sp. n. Aedeagus in ventral (7–8) and lateral (9–10) views, and 'sperm pump' (11).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1206420
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-03-24T13:30:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1206420
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Davies, Kerrie A.
# {http://datacite.org/schema/kernel-4}givenName
# Kerrie A.
# {http://datacite.org/schema/kernel-4}familyName
# Davies
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ye, Weimin
# {http://datacite.org/schema/kernel-4}givenName
# Weimin
# {http://datacite.org/schema/kernel-4}familyName
# Ye
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Taylor, Gary S.
# {http://datacite.org/schema/kernel-4}givenName
# Gary S.
# {http://datacite.org/schema/kernel-4}familyName
# Taylor
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Scheffer, Sonja
# {http://datacite.org/schema/kernel-4}givenName
# Sonja
# {http://datacite.org/schema/kernel-4}familyName
# Scheffer
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Bartholomaeus, F.
# {http://datacite.org/schema/kernel-4}givenName
# F.
# {http://datacite.org/schema/kernel-4}familyName
# Bartholomaeus
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Giblin-Davis, Robin M.
# {http://datacite.org/schema/kernel-4}givenName
# Robin M.
# {http://datacite.org/schema/kernel-4}familyName
# Giblin-Davis
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 7 in Nematodes from galls on Myrtaceae. XI. Descriptions of five new species of Fergusobia from Australia
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-03-20
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4399.1.1
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:7125507AC23AC82FFFA7FFA669136246
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1206406
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1206419
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 7. Fergusonina spp.: automontage image of Fergusonina pupa from ULPG on E.marginata, lacking a dorsal shield, and showing posterior gelatinous attachment.Scale bar = 1 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1206408
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-03-24T13:30:03Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1206408
# {http://datacite.org/schema/kernel-4}creators
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Davies, Kerrie A.
# {http://datacite.org/schema/kernel-4}givenName
# Kerrie A.
# {http://datacite.org/schema/kernel-4}familyName
# Davies
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ye, Weimin
# {http://datacite.org/schema/kernel-4}givenName
# Weimin
# {http://datacite.org/schema/kernel-4}familyName
# Ye
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Taylor, Gary S.
# {http://datacite.org/schema/kernel-4}givenName
# Gary S.
# {http://datacite.org/schema/kernel-4}familyName
# Taylor
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Scheffer, Sonja
# {http://datacite.org/schema/kernel-4}givenName
# Sonja
# {http://datacite.org/schema/kernel-4}familyName
# Scheffer
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Bartholomaeus, F.
# {http://datacite.org/schema/kernel-4}givenName
# F.
# {http://datacite.org/schema/kernel-4}familyName
# Bartholomaeus
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Giblin-Davis, Robin M.
# {http://datacite.org/schema/kernel-4}givenName
# Robin M.
# {http://datacite.org/schema/kernel-4}familyName
# Giblin-Davis
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 1. Fergusobia janetae n in Nematodes from galls on Myrtaceae. XI. Descriptions of five new species of Fergusobia from Australia
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2018
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Nematoda
# {http://datacite.org/schema/kernel-4}subject
# Chromadorea
# {http://datacite.org/schema/kernel-4}subject
# Tylenchida
# {http://datacite.org/schema/kernel-4}subject
# Fergusobiidae
# {http://datacite.org/schema/kernel-4}subject
# Fergusobia
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2018-03-20
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/8D1C2802C238C829FF30F9246DE9607B
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4399.1.1
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:7125507AC23AC82FFFA7FFA669136246
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/1206406
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1206407
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 1. Fergusobia janetae n. sp. ex E. marginata (all in lateral view): A, Entire parthenogenetic female; B, Anterior end of parthenogenetic female; C, Entire infective female; D, Entire male; E, Drawing of SEM of anterior end of parthenogenetic female; F, Habitus of parthenogenetic female; G; Tails of parthenogenetic female; H, Anterior end of male; I, Habitus of male; J, Tails of males; K, Lateral lines; L, Spicules. Scale bars: A, C, D = 50 µm; B, H = 25 µm; E, L = 5 µm. Tails and lateral lines not drawn to scale.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1205013
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2018-03-21T15:37:18Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.1205013
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Guglielmotti, Paola
# {http://datacite.org/schema/kernel-4}givenName
# Paola
# {http://datacite.org/schema/kernel-4}familyName
# Guglielmotti
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Un recupero tardivo: Nicolò Russo, Su le origini e la costituzione della "Potestatia Varaginis Cellarum et Arbisolae" (1908)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2016
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Territory
# {http://datacite.org/schema/kernel-4}subject
# Aristocracy
# {http://datacite.org/schema/kernel-4}subject
# Districts
# {http://datacite.org/schema/kernel-4}subject
# Historiography
# {http://datacite.org/schema/kernel-4}subject
# Erudition
# {http://datacite.org/schema/kernel-4}subject
# Genoa
# {http://datacite.org/schema/kernel-4}subject
# Savona
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2016-12-31
# {http://datacite.org/schema/kernel-4}language
# it
# {http://datacite.org/schema/kernel-4}resourceType
# None
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://storiapatriagenova.it/Scheda_vs_info.aspx?Id_Scheda_Bibliografica=5524
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 978-88-97099-34-5
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 2037-7134
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.1205012
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Closed Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# <p>Il lavoro &egrave; dedicato a un&rsquo;analitica presentazione e una valorizzazione del libro di Nicol&ograve; Russo, della cui biografia anche scientifica quasi nulla &egrave; accertabile. Russo considera l&rsquo;evo&not;luzione di un territorio situato tra Genova e Savona dall&rsquo;assogettamento &ldquo;feudale&rdquo; a un regime di maggior autonomia, una volta sotto governo genovese, delle tre comunit&agrave; che lo popolano. In questa dinamica emerge la famiglia genovese dei Malocelli, che tra fine secolo XII e il XIII svolge un importante ruolo proprietario e politico in quella che diventer&agrave; nel Trecento la po-desteria di Albisola, Celle e Varazze. Il testo propone un recupero di questa vicenda familiare rispetto a studi recentissimi dedicati alla storia di Genova.</p>
#
# <p>Parole chiave: Territorio, aristocrazia, circoscrizioni, storiografia, erudizione, Genova, Savona.</p>
#
# <p><br>
# The paper aims to evaluate and discuss analytically the book written by Nicol&ograve; Russo, an author whose life and scientific activities remain obscure. Russo considers the evolution of the territory between Genoa and Savona from the &ldquo;feudal&rdquo; subjection to a more autonomous regime (under Genoese government) of the three communities which inhabited the area. Against this backdrop, we can observe the Malocelli, a Genoese family which at the end of the XIIth and during the XIIIth century held an important role, both as landowners and political figures, in what would eventually become the podesteria of Albisola, Celle and Varazze (XIVth century). This study provides a reappraisal of the history of this family by considering also recent studies on Genoa.</p>
#
# <p>Keywords: Territory, Aristocracy, Districts, Historiography, Erudition, Genoa, Savona.</p>
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJwdjU8LgjAcQL_L7ywx12YoeMhSyFOa-e8iS5cMNxw6MBC_e9Y7vnd4K8ycd-Chg41dx0VHRF16opRgx4K5nUYpG7F3uJaRXZcxTQo6pCpHFe6D859c8vBWvJQ0aWhQ8tSPTkWXLAt0NmhS2XFUL74PFmjWc_CwBcPCpn4GbwXFDeuYYfeJv8Vn34xMND_RCsMJbNsX2ZoyKQ.Yc9hPg.3pat-d218gZLOIpm0DAaQ6f3FbU

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Muestra sólo el identificador y las palabras clave (subject)

# %%
base_url = 'https://zenodo.org/oai2d'
action = '?verb=ListRecords'
params =  '&metadataPrefix=oai_datacite4'
oai = requests.get(base_url + action + params)

xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()

for elem in iterator:
    if elem.tag == "{http://datacite.org/schema/kernel-4}identifier" or elem.tag == "{http://datacite.org/schema/kernel-4}subject":
        print(elem.tag, elem.text)
# Out:
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.3342065
# {http://datacite.org/schema/kernel-4}subject global exterior sheathing market, exterior sheathing market share, exterior sheathing market size, exterior sheathing market trends, exterior sheathing market growth, exterior sheathing market report, exterior sheathing market forecast, exterior sheathing
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1228465
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1227825
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopterygii
# {http://datacite.org/schema/kernel-4}subject Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject Bothidae
# {http://datacite.org/schema/kernel-4}subject Engyprosopon
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1227813
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopterygii
# {http://datacite.org/schema/kernel-4}subject Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject Bothidae
# {http://datacite.org/schema/kernel-4}subject Engyprosopon
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1227809
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopterygii
# {http://datacite.org/schema/kernel-4}subject Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject Bothidae
# {http://datacite.org/schema/kernel-4}subject Engyprosopon
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1227807
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopterygii
# {http://datacite.org/schema/kernel-4}subject Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject Bothidae
# {http://datacite.org/schema/kernel-4}subject Engyprosopon
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1227805
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopterygii
# {http://datacite.org/schema/kernel-4}subject Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject Bothidae
# {http://datacite.org/schema/kernel-4}subject Engyprosopon
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1227795
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopterygii
# {http://datacite.org/schema/kernel-4}subject Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject Bothidae
# {http://datacite.org/schema/kernel-4}subject Engyprosopon
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1227793
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopterygii
# {http://datacite.org/schema/kernel-4}subject Pleuronectiformes
# {http://datacite.org/schema/kernel-4}subject Bothidae
# {http://datacite.org/schema/kernel-4}subject Engyprosopon
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1226501
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Reptilia
# {http://datacite.org/schema/kernel-4}subject Squamata
# {http://datacite.org/schema/kernel-4}subject Chamaeleonidae
# {http://datacite.org/schema/kernel-4}subject Calumma
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1221856
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Arachnida
# {http://datacite.org/schema/kernel-4}subject Sarcoptiformes
# {http://datacite.org/schema/kernel-4}subject Otocepheidae
# {http://datacite.org/schema/kernel-4}subject Fissicepheus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1221854
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Arachnida
# {http://datacite.org/schema/kernel-4}subject Sarcoptiformes
# {http://datacite.org/schema/kernel-4}subject Otocepheidae
# {http://datacite.org/schema/kernel-4}subject Fissicepheus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1221148
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Desmodorida
# {http://datacite.org/schema/kernel-4}subject Comesomatidae
# {http://datacite.org/schema/kernel-4}subject Paracomesoma
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1221088
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Staphylinidae
# {http://datacite.org/schema/kernel-4}subject Mannerheimia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1221086
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Staphylinidae
# {http://datacite.org/schema/kernel-4}subject Mannerheimia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1221084
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Staphylinidae
# {http://datacite.org/schema/kernel-4}subject Mannerheimia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1216701
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1216516
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Mycetophilidae
# {http://datacite.org/schema/kernel-4}subject Allodia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1216510
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Mycetophilidae
# {http://datacite.org/schema/kernel-4}subject Allodia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1212943
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Amphibia
# {http://datacite.org/schema/kernel-4}subject Anura
# {http://datacite.org/schema/kernel-4}subject Bufonidae
# {http://datacite.org/schema/kernel-4}subject Peltophryne
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1209778
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Chironomidae
# {http://datacite.org/schema/kernel-4}subject Podonomus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1207176
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Muscidae
# {http://datacite.org/schema/kernel-4}subject Helina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1207174
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Muscidae
# {http://datacite.org/schema/kernel-4}subject Helina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1207172
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Muscidae
# {http://datacite.org/schema/kernel-4}subject Helina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1207168
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Muscidae
# {http://datacite.org/schema/kernel-4}subject Helina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1207166
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Muscidae
# {http://datacite.org/schema/kernel-4}subject Helina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1207164
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Muscidae
# {http://datacite.org/schema/kernel-4}subject Helina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206902
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Staphylinidae
# {http://datacite.org/schema/kernel-4}subject Nomuraius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206900
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Staphylinidae
# {http://datacite.org/schema/kernel-4}subject Nomuraius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206896
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Staphylinidae
# {http://datacite.org/schema/kernel-4}subject Nomuraius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206890
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206888
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Neuroptera
# {http://datacite.org/schema/kernel-4}subject Chrysopidae
# {http://datacite.org/schema/kernel-4}subject Parabaisochrysa
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206886
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Neuroptera
# {http://datacite.org/schema/kernel-4}subject Chrysopidae
# {http://datacite.org/schema/kernel-4}subject Parabaisochrysa
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206882
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Stomatopoda
# {http://datacite.org/schema/kernel-4}subject Nannosquillidae
# {http://datacite.org/schema/kernel-4}subject Madeirasquilla
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206880
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Stomatopoda
# {http://datacite.org/schema/kernel-4}subject Nannosquillidae
# {http://datacite.org/schema/kernel-4}subject Madeirasquilla
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206876
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Stomatopoda
# {http://datacite.org/schema/kernel-4}subject Nannosquillidae
# {http://datacite.org/schema/kernel-4}subject Madeirasquilla
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206860
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Spirurida
# {http://datacite.org/schema/kernel-4}subject Hystrignathidae
# {http://datacite.org/schema/kernel-4}subject Longior
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206854
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Spirurida
# {http://datacite.org/schema/kernel-4}subject Hystrignathidae
# {http://datacite.org/schema/kernel-4}subject Longior
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206852
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Spirurida
# {http://datacite.org/schema/kernel-4}subject Hystrignathidae
# {http://datacite.org/schema/kernel-4}subject Longior
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206850
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Spirurida
# {http://datacite.org/schema/kernel-4}subject Hystrignathidae
# {http://datacite.org/schema/kernel-4}subject Longior
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206848
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Spirurida
# {http://datacite.org/schema/kernel-4}subject Hystrignathidae
# {http://datacite.org/schema/kernel-4}subject Longior
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206846
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Spirurida
# {http://datacite.org/schema/kernel-4}subject Hystrignathidae
# {http://datacite.org/schema/kernel-4}subject Longior
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206844
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Spirurida
# {http://datacite.org/schema/kernel-4}subject Hystrignathidae
# {http://datacite.org/schema/kernel-4}subject Longior
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206838
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206832
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Decapoda
# {http://datacite.org/schema/kernel-4}subject Cambaridae
# {http://datacite.org/schema/kernel-4}subject Faxonius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206830
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Decapoda
# {http://datacite.org/schema/kernel-4}subject Cambaridae
# {http://datacite.org/schema/kernel-4}subject Faxonius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206826
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Decapoda
# {http://datacite.org/schema/kernel-4}subject Cambaridae
# {http://datacite.org/schema/kernel-4}subject Faxonius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206822
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206762
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopteri
# {http://datacite.org/schema/kernel-4}subject Gymnotiformes
# {http://datacite.org/schema/kernel-4}subject Sternopygidae
# {http://datacite.org/schema/kernel-4}subject Eigenmannia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206756
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopteri
# {http://datacite.org/schema/kernel-4}subject Gymnotiformes
# {http://datacite.org/schema/kernel-4}subject Sternopygidae
# {http://datacite.org/schema/kernel-4}subject Eigenmannia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206752
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Actinopteri
# {http://datacite.org/schema/kernel-4}subject Gymnotiformes
# {http://datacite.org/schema/kernel-4}subject Sternopygidae
# {http://datacite.org/schema/kernel-4}subject Eigenmannia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206744
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Coccinellidae
# {http://datacite.org/schema/kernel-4}subject Chnoodes
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206734
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Coccinellidae
# {http://datacite.org/schema/kernel-4}subject Chnoodes
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206728
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Dytiscidae
# {http://datacite.org/schema/kernel-4}subject Copelatus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206718
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Cumacea
# {http://datacite.org/schema/kernel-4}subject Lampropidae
# {http://datacite.org/schema/kernel-4}subject Hemilamprops
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206702
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Branchiopoda
# {http://datacite.org/schema/kernel-4}subject Diplostraca
# {http://datacite.org/schema/kernel-4}subject Limnadiidae
# {http://datacite.org/schema/kernel-4}subject Eulimnadia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206690
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Hymenoptera
# {http://datacite.org/schema/kernel-4}subject Megachilidae
# {http://datacite.org/schema/kernel-4}subject Trachusa
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206682
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Decapoda
# {http://datacite.org/schema/kernel-4}subject Palaemonidae
# {http://datacite.org/schema/kernel-4}subject Macrobrachium
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206672
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Decapoda
# {http://datacite.org/schema/kernel-4}subject Atyidae
# {http://datacite.org/schema/kernel-4}subject Caridina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206666
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Decapoda
# {http://datacite.org/schema/kernel-4}subject Atyidae
# {http://datacite.org/schema/kernel-4}subject Caridina
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206664
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206650
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Tardigrada
# {http://datacite.org/schema/kernel-4}subject Eutardigrada
# {http://datacite.org/schema/kernel-4}subject Parachela
# {http://datacite.org/schema/kernel-4}subject Hypsibiidae
# {http://datacite.org/schema/kernel-4}subject Hypsibius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206648
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Tardigrada
# {http://datacite.org/schema/kernel-4}subject Eutardigrada
# {http://datacite.org/schema/kernel-4}subject Parachela
# {http://datacite.org/schema/kernel-4}subject Hypsibiidae
# {http://datacite.org/schema/kernel-4}subject Hypsibius
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206634
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206630
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Sciaridae
# {http://datacite.org/schema/kernel-4}subject Aerumnosa
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206628
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Sciaridae
# {http://datacite.org/schema/kernel-4}subject Aerumnosa
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206624
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Reptilia
# {http://datacite.org/schema/kernel-4}subject Squamata
# {http://datacite.org/schema/kernel-4}subject Gekkonidae
# {http://datacite.org/schema/kernel-4}subject Cyrtodactylus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206606
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Amphibia
# {http://datacite.org/schema/kernel-4}subject Caudata
# {http://datacite.org/schema/kernel-4}subject Salamandridae
# {http://datacite.org/schema/kernel-4}subject Pachytriton
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206602
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Amphibia
# {http://datacite.org/schema/kernel-4}subject Caudata
# {http://datacite.org/schema/kernel-4}subject Salamandridae
# {http://datacite.org/schema/kernel-4}subject Pachytriton
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206584
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Orthoptera
# {http://datacite.org/schema/kernel-4}subject Tettigoniidae
# {http://datacite.org/schema/kernel-4}subject Atlanticus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206578
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206566
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Cerambycidae
# {http://datacite.org/schema/kernel-4}subject Eburia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206564
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Cerambycidae
# {http://datacite.org/schema/kernel-4}subject Eburia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206558
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Hymenoptera
# {http://datacite.org/schema/kernel-4}subject Ichneumonidae
# {http://datacite.org/schema/kernel-4}subject Exetastes
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206556
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Hymenoptera
# {http://datacite.org/schema/kernel-4}subject Ichneumonidae
# {http://datacite.org/schema/kernel-4}subject Exetastes
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206550
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Lepidoptera
# {http://datacite.org/schema/kernel-4}subject Gelechiidae
# {http://datacite.org/schema/kernel-4}subject Anarsia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206548
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Lepidoptera
# {http://datacite.org/schema/kernel-4}subject Gelechiidae
# {http://datacite.org/schema/kernel-4}subject Anarsia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206538
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Reptilia
# {http://datacite.org/schema/kernel-4}subject Squamata
# {http://datacite.org/schema/kernel-4}subject Colubridae
# {http://datacite.org/schema/kernel-4}subject Chersodromus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206530
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Reptilia
# {http://datacite.org/schema/kernel-4}subject Squamata
# {http://datacite.org/schema/kernel-4}subject Colubridae
# {http://datacite.org/schema/kernel-4}subject Chersodromus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206526
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Chordata
# {http://datacite.org/schema/kernel-4}subject Reptilia
# {http://datacite.org/schema/kernel-4}subject Squamata
# {http://datacite.org/schema/kernel-4}subject Colubridae
# {http://datacite.org/schema/kernel-4}subject Chersodromus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206520
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206516
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206512
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206508
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206506
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206504
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206502
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206500
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206498
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206496
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Malacostraca
# {http://datacite.org/schema/kernel-4}subject Isopoda
# {http://datacite.org/schema/kernel-4}subject Tridentellidae
# {http://datacite.org/schema/kernel-4}subject Tridentella
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206492
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Culicidae
# {http://datacite.org/schema/kernel-4}subject Toxorhynchites
# {http://datacite.org/schema/kernel-4}subject Wyeomyia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206486
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Diptera
# {http://datacite.org/schema/kernel-4}subject Culicidae
# {http://datacite.org/schema/kernel-4}subject Culex
# {http://datacite.org/schema/kernel-4}subject Lutzia
# {http://datacite.org/schema/kernel-4}subject Wyeomyia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206484
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206452
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206448
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206446
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206432
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Arthropoda
# {http://datacite.org/schema/kernel-4}subject Insecta
# {http://datacite.org/schema/kernel-4}subject Coleoptera
# {http://datacite.org/schema/kernel-4}subject Staphylinidae
# {http://datacite.org/schema/kernel-4}subject Clidicus
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206420
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1206408
# {http://datacite.org/schema/kernel-4}subject Biodiversity
# {http://datacite.org/schema/kernel-4}subject Taxonomy
# {http://datacite.org/schema/kernel-4}subject Animalia
# {http://datacite.org/schema/kernel-4}subject Nematoda
# {http://datacite.org/schema/kernel-4}subject Chromadorea
# {http://datacite.org/schema/kernel-4}subject Tylenchida
# {http://datacite.org/schema/kernel-4}subject Fergusobiidae
# {http://datacite.org/schema/kernel-4}subject Fergusobia
# {http://datacite.org/schema/kernel-4}identifier 10.5281/zenodo.1205013
# {http://datacite.org/schema/kernel-4}subject Territory
# {http://datacite.org/schema/kernel-4}subject Aristocracy
# {http://datacite.org/schema/kernel-4}subject Districts
# {http://datacite.org/schema/kernel-4}subject Historiography
# {http://datacite.org/schema/kernel-4}subject Erudition
# {http://datacite.org/schema/kernel-4}subject Genoa
# {http://datacite.org/schema/kernel-4}subject Savona

# %% [markdown]
# ## Filtros

# %% [markdown]
# Registros entre dos fechas

# %%
import xml.etree.ElementTree as ET

base_url = 'https://zenodo.org/oai2d'
action = '?verb=ListRecords'
params =  '&metadataPrefix=oai_datacite4'
bounds = "&from='2019-01-01'&until='2019-12-31'" #Para filtrar por fechas

oai = requests.get(base_url + action + params + bounds)
xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2021-12-31T20:00:06Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3342065
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-07-19T07:05:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.3342065
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# IMARC Services
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Exterior Sheathing Market: Global Industry Overview, Sales Revenue, Demand and Forecast by 2024
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# global exterior sheathing market, exterior sheathing market share, exterior sheathing market size, exterior sheathing market trends, exterior sheathing market growth, exterior sheathing market report, exterior sheathing market forecast, exterior sheathing
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-07-19
# {http://datacite.org/schema/kernel-4}resourceType
# Presentation
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.3342064
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# <p><strong>Get more information about the market: </strong><a href="https://www.imarcgroup.com/exterior-sheathing-market">https://www.imarcgroup.com/exterior-sheathing-market</a></p>
#
# <p>The global exterior sheathing market size reached US$ 6.6 Billion in 2018. Exterior sheathing is used in roofs, walls and floor assemblies to give a layer of protection against outside elements and to prevent wind and water from entering.</p>
#
# <p><strong>Want more information about this market? Request a free report sample: </strong><a href="https://www.imarcgroup.com/exterior-sheathing-market/requestsample">https://www.imarcgroup.com/exterior-sheathing-market/requestsample</a></p>
#
# <p><strong>For India market research reports, visit:</strong> <a href="http://www.marketresearchindia.co.in">http://www.marketresearchindia.co.in</a></p>
#
# <p>Contact Us</p>
#
# <p>IMARC Group<br>
# James Smith<br>
# Email: Sales@imarcgroup.com<br>
# Tel No:(D) +91 120 433 0800 | https://www.imarcgroup.com<br>
# Americas :- +1 631 791 1145 | Africa and Europe :- +44-702-409-7331<br>
# Linkedin: https://www.linkedin.com/company/imarc-group</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:955606
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-04-10T04:28:14Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# https://zenodo.org/record/955606
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Pinilla-Buitrago, Gonzalo
# {http://datacite.org/schema/kernel-4}givenName
# Gonzalo
# {http://datacite.org/schema/kernel-4}familyName
# Pinilla-Buitrago
# {http://datacite.org/schema/kernel-4}affiliation
# El Colegio de la Frontera Sur, Campeche, Campeche, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Martínez-Morales, Miguel Angel
# {http://datacite.org/schema/kernel-4}givenName
# Miguel Angel
# {http://datacite.org/schema/kernel-4}familyName
# Martínez-Morales
# {http://datacite.org/schema/kernel-4}affiliation
# El Colegio de la Frontera Sur, Campeche, Campeche, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# González-García, Fernando
# {http://datacite.org/schema/kernel-4}givenName
# Fernando
# {http://datacite.org/schema/kernel-4}familyName
# González-García
# {http://datacite.org/schema/kernel-4}affiliation
# Red de Biología y Conservación de Vertebrados, Instituto de Ecología, AC. Carretera antigua a Coatepec No. 351, El Haya, Xalapa, Veracruz, 91070, Mexi, Xalapa, Veracruz, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Enríquez, Paula L.
# {http://datacite.org/schema/kernel-4}givenName
# Paula L.
# {http://datacite.org/schema/kernel-4}familyName
# Enríquez
# {http://datacite.org/schema/kernel-4}affiliation
# El Colegio de la Frontera Sur, unidad San Cristóbal. Carretera Panamericana y Periférico Sur s/n, Barrio María Auxiliadora, San Cristóbal de Las Casas, San Cristóbal de Las Casas, Chiapas, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Rangel-Salazar, José Luis
# {http://datacite.org/schema/kernel-4}givenName
# José Luis
# {http://datacite.org/schema/kernel-4}familyName
# Rangel-Salazar
# {http://datacite.org/schema/kernel-4}affiliation
# El Colegio de la Frontera Sur, unidad San Cristóbal. Carretera Panamericana y Periférico Sur s/n, Barrio María Auxiliadora, San Cristóbal de Las Casas, San Cristóbal de Las Casas, Chiapas, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Guichard Romero, Carlos Alberto
# {http://datacite.org/schema/kernel-4}givenName
# Carlos Alberto
# {http://datacite.org/schema/kernel-4}familyName
# Guichard Romero
# {http://datacite.org/schema/kernel-4}affiliation
# Zoológico Miguel Álvarez del Toro. Calzada Cerro Hueco s/n, Colonia Zapotal, Apartado Postal 6, Tuxtla Gutiérrez, Chiapas, 29094, Mexico., Tuxtla Gutiérrez, Chiapas, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Navarro-Sigüenza, Adolfo
# {http://datacite.org/schema/kernel-4}givenName
# Adolfo
# {http://datacite.org/schema/kernel-4}familyName
# Navarro-Sigüenza
# {http://datacite.org/schema/kernel-4}affiliation
# Universidad Nacional Autónoma de México, Mexico DF, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Monterrubio-Rico, Tiberio César
# {http://datacite.org/schema/kernel-4}givenName
# Tiberio César
# {http://datacite.org/schema/kernel-4}familyName
# Monterrubio-Rico
# {http://datacite.org/schema/kernel-4}affiliation
# Facultad de Biología, Universidad Michoacana de San Nicolas de Hidalgo. Edificio R, Ciudad Universitaria, Morelia, Michoacán, 58000, Mexico., Morelia, Michoacán, Mexico
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Escalona-Segura, Griselda
# {http://datacite.org/schema/kernel-4}givenName
# Griselda
# {http://datacite.org/schema/kernel-4}familyName
# Escalona-Segura
# {http://datacite.org/schema/kernel-4}affiliation
# El Colegio de la Frontera Sur, unidad Campeche. Avenida Rancho Polígono 2-A, Ciudad Industrial Lerma, Campeche, Campeche, 24500, Mexico., Campeche, Campeche, Mexico
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Figure 5 from: Martínez-Morales M, Pinilla-Buitrago G, González-García F, Enríquez P, Rangel-Salazar J, Guichard Romero C, Navarro-Sigüenza A, Monterrubio-Rico T, Escalona-Segura G (2014) CracidMex1: a comprehensive database of global occurrences of cracids (Aves, Galliformes) with distribution in Mexico. ZooKeys 420: 87-115. https://doi.org/10.3897/zookeys.420.7050
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2014
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Ortalis
# {http://datacite.org/schema/kernel-4}subject
# Penelope
# {http://datacite.org/schema/kernel-4}subject
# Penelopina
# {http://datacite.org/schema/kernel-4}subject
# Oreophasis
# {http://datacite.org/schema/kernel-4}subject
# Crax
# {http://datacite.org/schema/kernel-4}subject
# Cracidae
# {http://datacite.org/schema/kernel-4}subject
# Aves
# {http://datacite.org/schema/kernel-4}subject
# chachalacas
# {http://datacite.org/schema/kernel-4}subject
# guans
# {http://datacite.org/schema/kernel-4}subject
# curassows
# {http://datacite.org/schema/kernel-4}subject
# Mexico
# {http://datacite.org/schema/kernel-4}subject
# Neotropic
# {http://datacite.org/schema/kernel-4}subject
# geographic record
# {http://datacite.org/schema/kernel-4}subject
# Darwin Core
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2014-06-25
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.3897/zookeys.420.7050
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.3897/zookeys.420.7050.figure5
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# Figure 5 - Geographic distribution of the 22,731 valid distributional records of cracids in the CracidMex1 database. Present pattern of forest cover is depicted in green shading. Forest cover was obtained from INEGI (2012) for Mexico, the World Bank and CCAD (2000) for Central America, and the European Commission Joint Research Centre (http://www-gem.jrc.it/glc2000) for South America.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:931813
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-10-09T16:26:29Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# https://zenodo.org/record/931813
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Houghton, David
# {http://datacite.org/schema/kernel-4}givenName
# David
# {http://datacite.org/schema/kernel-4}familyName
# Houghton
# {http://datacite.org/schema/kernel-4}affiliation
# University of Minnesota, Saint Paul, United States of America
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Figure 14 from: Houghton D (2012) Biological diversity of the Minnesota caddisflies (Insecta, Trichoptera). ZooKeys 189: 1-389. https://doi.org/10.3897/zookeys.189.2043
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2012
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Arthropoda
# {http://datacite.org/schema/kernel-4}subject
# Insecta
# {http://datacite.org/schema/kernel-4}subject
# Trichoptera
# {http://datacite.org/schema/kernel-4}subject
# Limnephiloidea
# {http://datacite.org/schema/kernel-4}subject
# Apataniidae
# {http://datacite.org/schema/kernel-4}subject
# Apatania
# {http://datacite.org/schema/kernel-4}subject
# Apatania zonella
# {http://datacite.org/schema/kernel-4}subject
# Trichoptera
# {http://datacite.org/schema/kernel-4}subject
# Minnesota
# {http://datacite.org/schema/kernel-4}subject
# caddisfly
# {http://datacite.org/schema/kernel-4}subject
# caddisflies
# {http://datacite.org/schema/kernel-4}subject
# fauna
# {http://datacite.org/schema/kernel-4}subject
# biodiversity
# {http://datacite.org/schema/kernel-4}subject
# identification
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2012-05-03
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.3897/zookeys.189.2043
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.3897/zookeys.189.2043.figure14
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# Figure 14 - Apatainia zonella A total specimens collected and all known collecting localities (Figure 4) B monthly adult abundance (1980s to present) C habitat preference (1980s to present) (Table 1) D male genital capsule E phallus.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:279297
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-10-09T09:48:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.279297
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Lapolla, John S.
# {http://datacite.org/schema/kernel-4}givenName
# John S.
# {http://datacite.org/schema/kernel-4}familyName
# Lapolla
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Hawkes, Peter G.
# {http://datacite.org/schema/kernel-4}givenName
# Peter G.
# {http://datacite.org/schema/kernel-4}familyName
# Hawkes
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Fisher, Brian L.
# {http://datacite.org/schema/kernel-4}givenName
# Brian L.
# {http://datacite.org/schema/kernel-4}familyName
# Fisher
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURES 92–94 in Monograph of Nylanderia (Hymenoptera: Formicidae) of the World, Part I: Nylanderia in the Afrotropics
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2011
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2011-12-31
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.279290
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:8B023408FFFAC13BFFC1FFA3FF81FFC2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://publication.plazi.org/id/8B023408FFFAC13BFFC1FFA3FF81FFC2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURES 92–94. Male (USNM #00753579; Central African Republic) genitalia of N. lepida
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2617144
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-04-10T03:29:17Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2617144
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Prasanna
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Advanced Financial Management
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Srinivas University Study Material
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-03-30
# {http://datacite.org/schema/kernel-4}resourceType
# None
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2617143
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Closed Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# <p>Srinivas University Study Material M.B.A III semester. 2018-2019.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2614119
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-09-28T02:07:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2614119
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Park, Kyu-Tek
# {http://datacite.org/schema/kernel-4}givenName
# Kyu-Tek
# {http://datacite.org/schema/kernel-4}familyName
# Park
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Prins, Willy De
# {http://datacite.org/schema/kernel-4}givenName
# Willy De
# {http://datacite.org/schema/kernel-4}familyName
# Prins
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 1 in Re-examination of the type specimens of Lecithoceridae (Lepidoptera), deposited in the Royal Museum for Central Africa (RMCA), Belgium, with descriptions of ten new species from DR Congo belonging to Thubdora Park and Torodora Meyrick
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-03-28
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4571.4.1
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:881A6C70FFD71207A06E75414F23FFDB
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/2614117
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://publication.plazi.org/id/881A6C70FFD71207A06E75414F23FFDB
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2614118
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 1. Map of DR Congo, with localities where material treated in this paper was collected. 1), Kinshasa, 4°19'S 15°18'E; 2), Eala, Province Equateur, 0°2'S 18°20'E; 3), Flandria, Province Equateur, 0°19'S 19°5'E; 4), Ekwangatana, Province Orientale, Bas-Uele, 2°53'N 24°5'E: 5), Garamba National Park, Province Orientale, Haut-Uele, 4°0'N 29°15'E; 6), Moku Moto, Province Orientale, Haut-Uele, 2°56'N 29°21'E; 7), Rutshuru, Province Nord-Kivu, 1°11'S 29°27'E; 8) Kibati, Province Nord-Kivu, 1°34'S 29°15'E; 9), Lusambo, Province East-Kasai, Sankuru, 4°58'S 23°26'E; 10), Kapiri, Province Katanga, Lualaba, 10°18'S 26°10'E; 11), Lubumbashi (Elisabethville), Province Katanga, Haut-Katanga, 11°39'S 27°28'E; 12), Katentanie, Province Katanga, Lualaba, 10°23'S 25°55'E; 13), Kapanga, Province Katanga, Lualaba, 8°21'S 22°35'E.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2600971
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-09-29T14:07:23Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2600971
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Heller, Klaus-Gerhard
# {http://datacite.org/schema/kernel-4}givenName
# Klaus-Gerhard
# {http://datacite.org/schema/kernel-4}familyName
# Heller
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 13 in Provisional checklist of the Tettigonioidea (Insecta: Orthoptera) from São Tomé & Príncipe with taxonomic remarks, bioacoustical data and the description of new taxa
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-02-28
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4563.1.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:9E5D29367D4C8A13E823FF8FFFCCFFA6
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/2600944
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://publication.plazi.org/id/9E5D29367D4C8A13E823FF8FFFCCFFA6
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2600970
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 13. Spectral composition of the callings songs of Conocephalus species.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2600967
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-09-29T14:07:00Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2600967
# {http://datacite.org/schema/kernel-4}creators
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Heller, Klaus-Gerhard
# {http://datacite.org/schema/kernel-4}givenName
# Klaus-Gerhard
# {http://datacite.org/schema/kernel-4}familyName
# Heller
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 11 in Provisional checklist of the Tettigonioidea (Insecta: Orthoptera) from São Tomé & Príncipe with taxonomic remarks, bioacoustical data and the description of new taxa
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-02-28
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4563.1.2
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:9E5D29367D4C8A13E823FF8FFFCCFFA6
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/2600944
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://publication.plazi.org/id/9E5D29367D4C8A13E823FF8FFFCCFFA6
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2600966
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 11. Oscillograms and frequency spectra of the calling song of Adapantus excavatus n. sp.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:273416
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-04-10T04:02:14Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.273416
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Akingbohungbe, A. E.
# {http://datacite.org/schema/kernel-4}givenName
# A. E.
# {http://datacite.org/schema/kernel-4}familyName
# Akingbohungbe
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURES 2, 3 in New species of Isometopinae (Hemiptera: Miridae) from Yemen with a new name for Isometopus longirostris Akingbohungbe from Sudan
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2006
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2006-12-31
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.273415
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:FFE76602FF946B7D980EAF42FFD3FFDF
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/273415
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/273415
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURES 2, 3. Isometopus vanharteni sp. nov. male, dorsal habitus; dorsal view of head.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2873277
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-05-16T14:00:54Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2873277
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Osborn, Henry Fairfield
# {http://datacite.org/schema/kernel-4}givenName
# Henry Fairfield
# {http://datacite.org/schema/kernel-4}familyName
# Osborn
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Fig 5 in Tyrannosaurus, upper Cretaceous carnivorous dinosaur. (Second communication.)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 1906
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 1906-12-31
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2873251
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:FFDEFFE8FFD7FF8F1241FFB8FFB3FFAC
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/2873251
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2873276
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# Fig 5. Sacrum of Tyrannosaurus. Amer. Mus. No. 973. I-5, sacrals x-5.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2864809
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-05-16T08:32:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-belgiumherbarium
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2864809
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Meise Botanic Garden
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Erica tetralix L. (BR0000010708095)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Terrestrial
# {http://datacite.org/schema/kernel-4}subject
# Herbarium
# {http://datacite.org/schema/kernel-4}subject
# Ericaceae
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-05-16
# {http://datacite.org/schema/kernel-4}resourceType
# Photo
# {http://datacite.org/schema/kernel-4}alternateIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}alternateIdentifier
# http://www.botanicalcollections.be/specimen/BR0000010708095
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2864808
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/belgiumherbarium
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution Share Alike 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# Belgium Herbarium image of <a href="https://www.plantentuinmeise.be">Meise Botanic Garden</a>.
# {http://datacite.org/schema/kernel-4}fundingReferences
#
#
# {http://datacite.org/schema/kernel-4}fundingReference
#
#
# {http://datacite.org/schema/kernel-4}funderName
# European Commission
# {http://datacite.org/schema/kernel-4}funderIdentifier
# 10.13039/501100000780
# {http://datacite.org/schema/kernel-4}awardNumber
# 777483
# {http://datacite.org/schema/kernel-4}awardTitle
# Innovation and consolidation for large scale digitisation of natural heritage
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2808864
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-05-14T08:18:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-belgiumherbarium
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2808864
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Meise Botanic Garden
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Dactylorhiza maculata (L.) Soó (BR0000011423607)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Terrestrial
# {http://datacite.org/schema/kernel-4}subject
# Herbarium
# {http://datacite.org/schema/kernel-4}subject
# Orchidaceae
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-05-14
# {http://datacite.org/schema/kernel-4}resourceType
# Photo
# {http://datacite.org/schema/kernel-4}alternateIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}alternateIdentifier
# http://www.botanicalcollections.be/specimen/BR0000011423607
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2808863
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/belgiumherbarium
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution Share Alike 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# Belgium Herbarium image of <a href="https://www.plantentuinmeise.be">Meise Botanic Garden</a>.
# {http://datacite.org/schema/kernel-4}fundingReferences
#
#
# {http://datacite.org/schema/kernel-4}fundingReference
#
#
# {http://datacite.org/schema/kernel-4}funderName
# European Commission
# {http://datacite.org/schema/kernel-4}funderIdentifier
# 10.13039/501100000780
# {http://datacite.org/schema/kernel-4}awardNumber
# 777483
# {http://datacite.org/schema/kernel-4}awardTitle
# Innovation and consolidation for large scale digitisation of natural heritage
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2808393
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-05-14T07:53:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-belgiumherbarium
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2808393
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Meise Botanic Garden
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Dactylorhiza incarnata (L.) Soó (BR0000011283652)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Terrestrial
# {http://datacite.org/schema/kernel-4}subject
# Herbarium
# {http://datacite.org/schema/kernel-4}subject
# Orchidaceae
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-05-14
# {http://datacite.org/schema/kernel-4}resourceType
# Photo
# {http://datacite.org/schema/kernel-4}alternateIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}alternateIdentifier
# http://www.botanicalcollections.be/specimen/BR0000011283652
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2808392
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/belgiumherbarium
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution Share Alike 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
# {http://datacite.org/schema/kernel-4}description
# Belgium Herbarium image of <a href="https://www.plantentuinmeise.be">Meise Botanic Garden</a>.
# {http://datacite.org/schema/kernel-4}fundingReferences
#
#
# {http://datacite.org/schema/kernel-4}fundingReference
#
#
# {http://datacite.org/schema/kernel-4}funderName
# European Commission
# {http://datacite.org/schema/kernel-4}funderIdentifier
# 10.13039/501100000780
# {http://datacite.org/schema/kernel-4}awardNumber
# 777483
# {http://datacite.org/schema/kernel-4}awardTitle
# Innovation and consolidation for large scale digitisation of natural heritage
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2800910
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-05-13T23:18:09Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-belgiumherbarium
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.2800910
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Meise Botanic Garden
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# Cephalanthera damasonium (Mill.) Druce (BR0000011419396)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Terrestrial
# {http://datacite.org/schema/kernel-4}subject
# Herbarium
# {http://datacite.org/schema/kernel-4}subject
# Orchidaceae
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-05-13
# {http://datacite.org/schema/kernel-4}resourceType
# Photo
# {http://datacite.org/schema/kernel-4}alternateIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}alternateIdentifier
# http://www.botanicalcollections.be/specimen/BR0000011419396
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.2800909
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/belgiumherbarium
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Creative Commons Attribution Share Alike 4.0 International
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# Belgium Herbarium image of <a href="https://www.plantentuinmeise.be">Meise Botanic Garden</a>.
# {http://datacite.org/schema/kernel-4}fundingReferences
#
#
# {http://datacite.org/schema/kernel-4}fundingReference
#
#
# {http://datacite.org/schema/kernel-4}funderName
# European Commission
# {http://datacite.org/schema/kernel-4}funderIdentifier
# 10.13039/501100000780
# {http://datacite.org/schema/kernel-4}awardNumber
# 777483
# {http://datacite.org/schema/kernel-4}awardTitle
# Innovation and consolidation for large scale digitisation of natural heritage
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2799448
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-05-13T22:08:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-belgiumherbarium
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# ...
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.3619.3.4
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:F308AB1C5F7962318426FFD6FF82FF89
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/219688
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.3619.3.4
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/219688
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 2. Phytogeographical sub-regions of Australia (excluding New Guinea).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:343771
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-10-20T20:07:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.343771
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Martín, Guillermo San
# {http://datacite.org/schema/kernel-4}givenName
# Guillermo San
# {http://datacite.org/schema/kernel-4}familyName
# Martín
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Álvarez-Campos, Patricia
# {http://datacite.org/schema/kernel-4}givenName
# Patricia
# {http://datacite.org/schema/kernel-4}familyName
# Álvarez-Campos
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Hutchings, Pat
# {http://datacite.org/schema/kernel-4}givenName
# Pat
# {http://datacite.org/schema/kernel-4}familyName
# Hutchings
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 15 in The genus Syllis Savigny in Lamarck, 1818 (Annelida: Syllidae: Syllinae) from Australia (second part): four new species and re-description of twelve previously described species
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2017
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Annelida
# {http://datacite.org/schema/kernel-4}subject
# Polychaeta
# {http://datacite.org/schema/kernel-4}subject
# Phyllodocida
# {http://datacite.org/schema/kernel-4}subject
# Syllidae
# {http://datacite.org/schema/kernel-4}subject
# Syllis
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2017-12-31
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4237.2.1
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:5F51FFC15A5BFFC7FF85D2321D2DFFC6
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://publication.plazi.org/id/5F51FFC15A5BFFC7FF85D2321D2DFFC6
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/343756
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.3510404
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/A36887B95A43FFDCFF12D0BD1C46F95D
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 15. Syllis monilaris Savigny in Lamarck, 1818 (AM W.29492). A, compound chaetae, anterior parapodium. B, compound chaetae, midbody parapodium. C, compound chaetae, posterior parapodium. D, aciculae, anterior parapodium. E, aciculae, midbody parapodium. F, aciculae, posterior parapodium. Scale bars: A–F: 20 µm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:256477
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-04-10T04:01:08Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.256477
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Coppard, Simon E.
# {http://datacite.org/schema/kernel-4}givenName
# Simon E.
# {http://datacite.org/schema/kernel-4}familyName
# Coppard
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 3 in A new genus of mellitid sand dollar (Echinoidea: Mellitidae) from the eastern Pacific coast of the Americas
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2016
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2016-12-31
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4111.2.4
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:475D6B74FE07A63DB809FFE1FFB8FFC6
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4111.2.4
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/256474
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 3. Denuded tests (i aboral, ii oral, iii lateral-view, anterior to right) of: A, M. quinquiesperforata (San Blas, Panama); B, M. tenuis (Florida, USA); C, M. notabilis (Michoacan, Mexico, high wave-energy ecophenotype); D, M. notabilis (Las Lajas, Panama, low wave-energy ecophenotype); E, L. longifissa (Bahia Magdalena, Mexico, high wave-energy ecophenotype); F, L. longifissa (Punta Chame, Panama, low wave-energy ecophenotype); G, L. grantii (Malcomb, Mexico, high wave-energy ecophenotype), H, L. grantii (Bahia de Kino, Mexico, low wave-energy ecophenotype).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3576909
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-12-16T07:16:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.3576909
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Li, Xuankun
# {http://datacite.org/schema/kernel-4}givenName
# Xuankun
# {http://datacite.org/schema/kernel-4}familyName
# Li
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Yeates, David K.
# {http://datacite.org/schema/kernel-4}givenName
# David K.
# {http://datacite.org/schema/kernel-4}familyName
# Yeates
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 28 in Revision of the Australian bee fly genus Sisyromyia White, 1916 (Bombyliidae, Bombyliinae, Acrophthalmydini)
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2019
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}subject
# Animalia
# {http://datacite.org/schema/kernel-4}subject
# Arthropoda
# {http://datacite.org/schema/kernel-4}subject
# Insecta
# {http://datacite.org/schema/kernel-4}subject
# Diptera
# {http://datacite.org/schema/kernel-4}subject
# Bombyliidae
# {http://datacite.org/schema/kernel-4}subject
# Dissodesma
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2019-12-16
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.11646/zootaxa.4711.2.1
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:761EBF51517EBC2DFFCDFFB9380FFA75
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://publication.plazi.org/id/761EBF51517EBC2DFFCDFFB9380FFA75
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/3576849
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# http://treatment.plazi.org/id/8A27C7295158BC0AFF5AFF583AD4FF92
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.3576908
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 28. Dissodesma binghi (Evenhuis, 1989) comb. nov. Genitalia (a–e (♂); f, g (♀)): (a) genitalic capsule, dorsal; (b) genitalic capsule, ventral; (c) genitalic capsule, lateral; (d) epandrium, dorsal; (e) epandrium, lateral; (f) sternite 8, ventral; (g) genitalia and spermathecae. Scale bars = 0.1 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:176979
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-04-10T03:51:12Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-4}resource
#
#
# {http://datacite.org/schema/kernel-4}identifier
# 10.5281/zenodo.176979
# {http://datacite.org/schema/kernel-4}creators
#
#
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Ziegler, Thomas
# {http://datacite.org/schema/kernel-4}givenName
# Thomas
# {http://datacite.org/schema/kernel-4}familyName
# Ziegler
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Hendrix, Ralf
# {http://datacite.org/schema/kernel-4}givenName
# Ralf
# {http://datacite.org/schema/kernel-4}familyName
# Hendrix
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Thanh, Vu Ngoc
# {http://datacite.org/schema/kernel-4}givenName
# Vu Ngoc
# {http://datacite.org/schema/kernel-4}familyName
# Thanh
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Vogt, Martina
# {http://datacite.org/schema/kernel-4}givenName
# Martina
# {http://datacite.org/schema/kernel-4}familyName
# Vogt
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Forster, Bernhard
# {http://datacite.org/schema/kernel-4}givenName
# Bernhard
# {http://datacite.org/schema/kernel-4}familyName
# Forster
# {http://datacite.org/schema/kernel-4}creator
#
#
# {http://datacite.org/schema/kernel-4}creatorName
# Kien, Dang Ngoc
# {http://datacite.org/schema/kernel-4}givenName
# Dang Ngoc
# {http://datacite.org/schema/kernel-4}familyName
# Kien
# {http://datacite.org/schema/kernel-4}titles
#
#
# {http://datacite.org/schema/kernel-4}title
# FIGURE 19 in The diversity of a snake community in a karst forest ecosystem in the central Truong Son, Vietnam, with an identification key
# {http://datacite.org/schema/kernel-4}publisher
# Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear
# 2007
# {http://datacite.org/schema/kernel-4}subjects
#
#
# {http://datacite.org/schema/kernel-4}subject
# Biodiversity
# {http://datacite.org/schema/kernel-4}subject
# Taxonomy
# {http://datacite.org/schema/kernel-4}dates
#
#
# {http://datacite.org/schema/kernel-4}date
# 2007-12-31
# {http://datacite.org/schema/kernel-4}resourceType
# Figure
# {http://datacite.org/schema/kernel-4}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# 10.5281/zenodo.176960
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# urn:lsid:plazi.org:pub:FF95FFA8B115FF9EFFD19607FFD28827
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/176960
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/record/176960
# {http://datacite.org/schema/kernel-4}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList
#
#
# {http://datacite.org/schema/kernel-4}rights
# Open Access
# {http://datacite.org/schema/kernel-4}descriptions
#
#
# {http://datacite.org/schema/kernel-4}description
# FIGURE 19. Distribution pattern of snake species recorded from Phong Nha - Ke Bang.
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJxVjMsOgjAURP_lrolpERRJXPhi4coHgrAxFa6koZWmrWJi-HerO2c558y8wSDWEJMRDch4GkVhRIk_CaezsQem0p0QF-44rM8JLc_bcJ-H7UFmpPCb5eKXTOCmyq9S2MPGkv1JHWuZrNJ0qdJWBQXdJmU_n4MHijUIse9B2zPdGIjfcNOddOcKteTG8Cc6TaJlNbNsp_HGX452jF--RcUtBk543C0X_6th-AABnkCM.Yc9hRg.8vZNNkBvov9sH_k50OhRjKCGF8Y

# %% [markdown]
# ### GetRecord
#
# This verb is used to retrieve an individual metadata record from a repository. Required arguments specify the identifier of the item from which the record is requested and the format of the metadata that should be included in the record. Depending on the level at which a repository tracks deletions, a header with a "deleted" value for the status attribute may be returned, in case the metadata format specified by the metadataPrefix is no longer available from the repository or from the specified item.
#
# Obtener objeto digital de ese recurso

# %%
import xml.etree.ElementTree as ET
import urllib

base_url = 'https://zenodo.org/oai2d'
action = '?verb=GetRecord'
params =  '&metadataPrefix=oai_datacite4&identifier=oai:zenodo.org:3363479'
print(base_url + action + params)
oai = requests.get(base_url + action + params)
print(oai.text)
xmlTree = ET.fromstring(oai.text)
ns = {'oai' : 'http://www.openarchives.org/OAI/2.0/'}

#iterator = xmlTree.iter()
#for elem in iterator:
 #   print(elem.tag)
 #   print(elem.text)

for tags in xmlTree.findall('.//',ns):
    print (tags.tag+": ",tags.text)
# Out:
# https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_datacite4&identifier=oai:zenodo.org:3363479
# <?xml version='1.0' encoding='UTF-8'?>
# <?xml-stylesheet type="text/xsl" href="/static/xsl/oai2.xsl"?>
# <OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">
#   <responseDate>2021-12-31T20:00:11Z</responseDate>
#   <request verb="GetRecord" metadataPrefix="oai_datacite4" identifier="oai:zenodo.org:3363479">https://zenodo.org/oai2d</request>
#   <GetRecord>
#     <record>
#       <header>
#         <identifier>oai:zenodo.org:3363479</identifier>
#         <datestamp>2021-10-20T05:26:47Z</datestamp>
#         <setSpec>user-biosyslit</setSpec>
#       </header>
#       <metadata>
#         <oai_datacite xmlns="http://schema.datacite.org/oai/oai-1.0/" xsi:schemaLocation="http://schema.datacite.org/oai/oai-1.0/ oai_datacite.xsd">
#           <isReferenceQuality>true</isReferenceQuality>
#           <schemaVersion>4.1</schemaVersion>
#           <datacentreSymbol>CERN.ZENODO</datacentreSymbol>
#           <payload>
#             <resource xmlns="http://datacite.org/schema/kernel-4" xsi:schemaLocation="http://datacite.org/schema/kernel-4 http://schema.datacite.org/meta/kernel-4.1/metadata.xsd">
#               <identifier identifierType="DOI">10.5281/zenodo.3363479</identifier>
#               <creators>
#                 <creator>
#                   <creatorName>Kirichenko, Natalia</creatorName>
#                   <givenName>Natalia</givenName>
#                   <familyName>Kirichenko</familyName>
#                 </creator>
#                 <creator>
#                   <creatorName>Triberti, Paolo</creatorName>
#                   <givenName>Paolo</givenName>
#                   <familyName>Triberti</familyName>
#                 </creator>
#                 <creator>
#                   <creatorName>Akulov, Evgeniy</creatorName>
#                   <givenName>Evgeniy</givenName>
#                   <familyName>Akulov</familyName>
#                 </creator>
#                 <creator>
#                   <creatorName>Ponomarenko, Margarita</creatorName>
#                   <givenName>Margarita</givenName>
#                   <familyName>Ponomarenko</familyName>
#                 </creator>
#                 <creator>
#                   <creatorName>Gorokhova, Svetlana</creatorName>
#                   <givenName>Svetlana</givenName>
#                   <familyName>Gorokhova</familyName>
#                 </creator>
#                 <creator>
#                   <creatorName>Sheiko, Viktor</creatorName>
#                   <givenName>Viktor</givenName>
#                   <familyName>Sheiko</familyName>
#                 </creator>
#                 <creator>
#                   <creatorName>Ohshima, Issei</creatorName>
#                   <givenName>Issei</givenName>
#                   <familyName>Ohshima</familyName>
#                 </creator>
#                 <creator>
#                   <creatorName>Lopez-Vaamonde, Carlos</creatorName>
#                   <givenName>Carlos</givenName>
#                   <familyName>Lopez-Vaamonde</familyName>
#                 </creator>
#               </creators>
#               <titles>
#                 <title>FIGURE 2 in Exploring species diversity and host plant associations of leaf-mining micromoths (Lepidoptera: Gracillariidae) in the Russian Far East using DNA barcoding</title>
#               </titles>
#               <publisher>Zenodo</publisher>
#               <publicationYear>2019</publicationYear>
#               <subjects>
#                 <subject>Biodiversity</subject>
#                 <subject>Taxonomy</subject>
#               </subjects>
#               <dates>
#                 <date dateType="Issued">2019-08-07</date>
#               </dates>
#               <resourceType resourceTypeGeneral="Image">Figure</resourceType>
#               <alternateIdentifiers>
#                 <alternateIdentifier alternateIdentifierType="url">https://zenodo.org/record/3363479</alternateIdentifier>
#               </alternateIdentifiers>
#               <relatedIdentifiers>
#                 <relatedIdentifier relatedIdentifierType="DOI" relationType="IsPartOf" resourceTypeGeneral="JournalArticle">10.11646/zootaxa.4652.1.1</relatedIdentifier>
#                 <relatedIdentifier relatedIdentifierType="LSID" relationType="IsPartOf" resourceTypeGeneral="JournalArticle">urn:lsid:plazi.org:pub:B364FFF32541E068FFEEBA42FFEDFF82</relatedIdentifier>
#                 <relatedIdentifier relatedIdentifierType="URL" relationType="IsPartOf" resourceTypeGeneral="JournalArticle">http://publication.plazi.org/id/B364FFF32541E068FFEEBA42FFEDFF82</relatedIdentifier>
#                 <relatedIdentifier relatedIdentifierType="URL" relationType="IsPartOf" resourceTypeGeneral="JournalArticle">https://zenodo.org/record/3363475</relatedIdentifier>
#                 <relatedIdentifier relatedIdentifierType="DOI" relationType="IsVersionOf">10.5281/zenodo.3363478</relatedIdentifier>
#                 <relatedIdentifier relatedIdentifierType="URL" relationType="IsPartOf">https://zenodo.org/communities/biosyslit</relatedIdentifier>
#               </relatedIdentifiers>
#               <rightsList>
#                 <rights rightsURI="info:eu-repo/semantics/openAccess">Open Access</rights>
#               </rightsList>
#               <descriptions>
#                 <description descriptionType="Abstract">FIGURE 2. Sampling localities in the Russian Far East. (A–C) PK, Gornotaezhnoe, MTS: (A) European woody plant species zone, (B) Juglans mandshurica plantation, (C) East Asian woody plant species zone; (D) PK, 20 km west of MTS, artificial lake on the way to Glukhovka and Rakovka; (E–H) SO, Sakhalin Isl., Susunay mountain range: (E–G) pass "Verblud", sampling and camping area, (H) foothills of the Susunay mountain range, the Erman's birch groove. Personalities: (C) S. Gorokhova, (F) V. Sheiko, (H) N. Kirichenko (the photographs are published with the permission of SG, VS and NK). (PK) Primorskii Krai, (SO) Sakhalinskaya Oblast (includes Sakhalin Island and Kuril Islands).</description>
#                 <description descriptionType="Other">Published as part of &lt;i&gt;Kirichenko, Natalia, Triberti, Paolo, Akulov, Evgeniy, Ponomarenko, Margarita, Gorokhova, Svetlana, Sheiko, Viktor, Ohshima, Issei &amp;amp; Lopez-Vaamonde, Carlos, 2019, Exploring species diversity and host plant associations of leaf-mining micromoths (Lepidoptera: Gracillariidae) in the Russian Far East using DNA barcoding, pp. 1-55 in Zootaxa 4652 (1)&lt;/i&gt; on page 10, DOI: 10.11646/zootaxa.4652.1.1, &lt;a href="http://zenodo.org/record/3363475"&gt;http://zenodo.org/record/3363475&lt;/a&gt;</description>
#               </descriptions>
#             </resource>
#           </payload>
#         </oai_datacite>
#       </metadata>
#     </record>
#   </GetRecord>
# </OAI-PMH>
#
# {http://www.openarchives.org/OAI/2.0/}responseDate:  2021-12-31T20:00:11Z
# {http://www.openarchives.org/OAI/2.0/}request:  https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}GetRecord:
#
# {http://www.openarchives.org/OAI/2.0/}record:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier:  oai:zenodo.org:3363479
# {http://www.openarchives.org/OAI/2.0/}datestamp:  2021-10-20T05:26:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec:  user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata:
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite:
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality:  true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion:  4.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol:  CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload:
#
# {http://datacite.org/schema/kernel-4}resource:
#
# {http://datacite.org/schema/kernel-4}identifier:  10.5281/zenodo.3363479
# {http://datacite.org/schema/kernel-4}creators:
#
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Kirichenko, Natalia
# {http://datacite.org/schema/kernel-4}givenName:  Natalia
# {http://datacite.org/schema/kernel-4}familyName:  Kirichenko
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Triberti, Paolo
# {http://datacite.org/schema/kernel-4}givenName:  Paolo
# {http://datacite.org/schema/kernel-4}familyName:  Triberti
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Akulov, Evgeniy
# {http://datacite.org/schema/kernel-4}givenName:  Evgeniy
# {http://datacite.org/schema/kernel-4}familyName:  Akulov
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Ponomarenko, Margarita
# {http://datacite.org/schema/kernel-4}givenName:  Margarita
# {http://datacite.org/schema/kernel-4}familyName:  Ponomarenko
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Gorokhova, Svetlana
# {http://datacite.org/schema/kernel-4}givenName:  Svetlana
# {http://datacite.org/schema/kernel-4}familyName:  Gorokhova
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Sheiko, Viktor
# {http://datacite.org/schema/kernel-4}givenName:  Viktor
# {http://datacite.org/schema/kernel-4}familyName:  Sheiko
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Ohshima, Issei
# {http://datacite.org/schema/kernel-4}givenName:  Issei
# {http://datacite.org/schema/kernel-4}familyName:  Ohshima
# {http://datacite.org/schema/kernel-4}creator:
#
# {http://datacite.org/schema/kernel-4}creatorName:  Lopez-Vaamonde, Carlos
# {http://datacite.org/schema/kernel-4}givenName:  Carlos
# {http://datacite.org/schema/kernel-4}familyName:  Lopez-Vaamonde
# {http://datacite.org/schema/kernel-4}titles:
#
# {http://datacite.org/schema/kernel-4}title:  FIGURE 2 in Exploring species diversity and host plant associations of leaf-mining micromoths (Lepidoptera: Gracillariidae) in the Russian Far East using DNA barcoding
# {http://datacite.org/schema/kernel-4}publisher:  Zenodo
# {http://datacite.org/schema/kernel-4}publicationYear:  2019
# {http://datacite.org/schema/kernel-4}subjects:
#
# {http://datacite.org/schema/kernel-4}subject:  Biodiversity
# {http://datacite.org/schema/kernel-4}subject:  Taxonomy
# {http://datacite.org/schema/kernel-4}dates:
#
# {http://datacite.org/schema/kernel-4}date:  2019-08-07
# {http://datacite.org/schema/kernel-4}resourceType:  Figure
# {http://datacite.org/schema/kernel-4}alternateIdentifiers:
#
# {http://datacite.org/schema/kernel-4}alternateIdentifier:  https://zenodo.org/record/3363479
# {http://datacite.org/schema/kernel-4}relatedIdentifiers:
#
# {http://datacite.org/schema/kernel-4}relatedIdentifier:  10.11646/zootaxa.4652.1.1
# {http://datacite.org/schema/kernel-4}relatedIdentifier:  urn:lsid:plazi.org:pub:B364FFF32541E068FFEEBA42FFEDFF82
# {http://datacite.org/schema/kernel-4}relatedIdentifier:  http://publication.plazi.org/id/B364FFF32541E068FFEEBA42FFEDFF82
# {http://datacite.org/schema/kernel-4}relatedIdentifier:  https://zenodo.org/record/3363475
# {http://datacite.org/schema/kernel-4}relatedIdentifier:  10.5281/zenodo.3363478
# {http://datacite.org/schema/kernel-4}relatedIdentifier:  https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-4}rightsList:
#
# {http://datacite.org/schema/kernel-4}rights:  Open Access
# {http://datacite.org/schema/kernel-4}descriptions:
#
# {http://datacite.org/schema/kernel-4}description:  FIGURE 2. Sampling localities in the Russian Far East. (A–C) PK, Gornotaezhnoe, MTS: (A) European woody plant species zone, (B) Juglans mandshurica plantation, (C) East Asian woody plant species zone; (D) PK, 20 km west of MTS, artificial lake on the way to Glukhovka and Rakovka; (E–H) SO, Sakhalin Isl., Susunay mountain range: (E–G) pass "Verblud", sampling and camping area, (H) foothills of the Susunay mountain range, the Erman's birch groove. Personalities: (C) S. Gorokhova, (F) V. Sheiko, (H) N. Kirichenko (the photographs are published with the permission of SG, VS and NK). (PK) Primorskii Krai, (SO) Sakhalinskaya Oblast (includes Sakhalin Island and Kuril Islands).
# {http://datacite.org/schema/kernel-4}description:  Published as part of <i>Kirichenko, Natalia, Triberti, Paolo, Akulov, Evgeniy, Ponomarenko, Margarita, Gorokhova, Svetlana, Sheiko, Viktor, Ohshima, Issei &amp; Lopez-Vaamonde, Carlos, 2019, Exploring species diversity and host plant associations of leaf-mining micromoths (Lepidoptera: Gracillariidae) in the Russian Far East using DNA barcoding, pp. 1-55 in Zootaxa 4652 (1)</i> on page 10, DOI: 10.11646/zootaxa.4652.1.1, <a href="http://zenodo.org/record/3363475">http://zenodo.org/record/3363475</a>

# %% [markdown]
# ## APIs específicas

# %% [markdown]
# El protocolo OAI-PMH ofrece una serie de funcionalidades genéricas e interoperables entre distintos repositorios. Sin embargo, existen ciertas limitaciones que no nos permiten automatizar todo lo necesario para analizar un gran número de dataset. Para ello, tenemos que recurrir a APIs específicas de los repositorios con los que trabajamos.
#
# Zenodo proporciona una API bastante completa que complementa al protocolo OAI-PMH. En el siguiente enlace podemos ver su especificación y algunos ejemplos con curl y python.
#
# http://developers.zenodo.org/
#
# Entre otras cosas, podemos automatizar el proceso de publicación, descargar archivos, etc.
#
# También, obteniendo el DOI de un recurso, podemos resolverlo para obtener cierta información específica, como la URL del objeto digital entre otras.

# %%
import json
#Buscamos datasets específicos-
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=datacite3')
oaiTree = ET.fromstring(oai.text)
#for i in oaiTree.iter():
#    print(i.tag)
records = oaiTree.findall('.//{http://www.openarchives.org/OAI/2.0/}record')
for e in records:
    for subject in e.findall('.//{http://datacite.org/schema/kernel-3}subject'):
        if "Animalia" in subject.text:
            print("Title: "+e.findall('.//{http://datacite.org/schema/kernel-3}title')[0].text)
            identifier = e.findall('.//{http://datacite.org/schema/kernel-3}identifier')[0].text
            print(identifier)
            print('\n')
            
headers = {'accept': 'application/json'}
r = requests.get('https://zenodo.org/api/records/958140',headers)
record = json.loads(r.text)
print(record['files'])
# Out:
# Title: FIGURE 17 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# 10.5281/zenodo.1227825
#
#
# Title: FIGURE 11 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# 10.5281/zenodo.1227813
#
#
# Title: FIGURE 9 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# 10.5281/zenodo.1227809
#
#
# Title: FIGURE 8 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# 10.5281/zenodo.1227807
#
#
# Title: FIGURE 7 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# 10.5281/zenodo.1227805
#
#
# Title: FIGURE 2 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# 10.5281/zenodo.1227795
#
#
# Title: FIGURE 1. Engyprosopon xystrias Hubbs, 1915. NMMB-P22216 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# 10.5281/zenodo.1227793
#
#
# Title: Figure 7 in Endangered beauties: micro-CT cranial osteology, molecular genetics and external morphology reveal three new species of chameleons in the Calumma boettgeri complex (Squamata: Chamaeleonidae)
# 10.5281/zenodo.1226501
#
#
# Title: FIGURE 4 in Taxonomic study on the genus Fissicepheus (Acari: Oribatida: Otocepheidae) from China
# 10.5281/zenodo.1221856
#
#
# Title: FIGURE 3 in Taxonomic study on the genus Fissicepheus (Acari: Oribatida: Otocepheidae) from China
# 10.5281/zenodo.1221854
#
#
# Title: FIGURE 1 in Two new species of Comesomatidae (Nematoda) from the East China Sea
# 10.5281/zenodo.1221148
#
#
# Title: FIGURE 11 in Four new species of the genus Mannerheimia Mäklin, 1880 (Coleoptera: Staphylinidae: Omaliinae) from south-western China and Taiwan
# 10.5281/zenodo.1221088
#
#
# Title: FIGURES 9–10 in Four new species of the genus Mannerheimia Mäklin, 1880 (Coleoptera: Staphylinidae: Omaliinae) from south-western China and Taiwan
# 10.5281/zenodo.1221086
#
#
# Title: FIGURES 5–8 in Four new species of the genus Mannerheimia Mäklin, 1880 (Coleoptera: Staphylinidae: Omaliinae) from south-western China and Taiwan
# 10.5281/zenodo.1221084
#
#
# Title: FIGURE 7 in Six new species of Afrotropical Allodia (Diptera: Mycetophilidae): DNA barcodes indicate recent diversification with a single origin
# 10.5281/zenodo.1216516
#
#
# Title: FIGURE 4 in Six new species of Afrotropical Allodia (Diptera: Mycetophilidae): DNA barcodes indicate recent diversification with a single origin
# 10.5281/zenodo.1216510
#
#
# Title: FIGURE 1 in A new species of Caribbean toad (Bufonidae, Peltophryne) from southern Hispaniola
# 10.5281/zenodo.1212943
#
#
# Title: FIGURE 2. A–D in Podonomus amarali n. sp., a new species of the albinervis group (Diptera: Chironomidae: Podonominae) from Atlantic Forest, southern Brazil
# 10.5281/zenodo.1209778
#
#
# Title: FIGURES 48–51 in The male terminalia of some African species of Helina Robineau-Desvoidy, 1830 (Diptera, Muscidae)
# 10.5281/zenodo.1207176
#
#
# Title: FIGURES 42–47. Helina penicillata Emden, 1951 in The male terminalia of some African species of Helina Robineau-Desvoidy, 1830 (Diptera, Muscidae)
# 10.5281/zenodo.1207174
#
#
# Title: FIGURES 35–41 in The male terminalia of some African species of Helina Robineau-Desvoidy, 1830 (Diptera, Muscidae)
# 10.5281/zenodo.1207172
#
#
# Title: FIGURES 20–27. Helina juxtamedialis Emden, 1951 in The male terminalia of some African species of Helina Robineau-Desvoidy, 1830 (Diptera, Muscidae)
# 10.5281/zenodo.1207168
#
#
# Title: FIGURES 17–19. Helina hirtipes metatarsalis Emden, 1951 in The male terminalia of some African species of Helina Robineau-Desvoidy, 1830 (Diptera, Muscidae)
# 10.5281/zenodo.1207166
#
#
# Title: FIGURES 9–16. Helina fuscibasis Emden, 1951 in The male terminalia of some African species of Helina Robineau-Desvoidy, 1830 (Diptera, Muscidae)
# 10.5281/zenodo.1207164
#
#
# Title: FIGURE 5 in Two new species of Nomuraius Hlaváč (Coleoptera: Staphylinidae: Pselaphinae) from southern China
# 10.5281/zenodo.1206902
#
#
# Title: FIGURE 4 in Two new species of Nomuraius Hlaváč (Coleoptera: Staphylinidae: Pselaphinae) from southern China
# 10.5281/zenodo.1206900
#
#
# Title: FIGURE 2 in Two new species of Nomuraius Hlaváč (Coleoptera: Staphylinidae: Pselaphinae) from southern China
# 10.5281/zenodo.1206896
#
#
# Title: FIGURE 2 in The first green lacewing (Insecta: Neuroptera: Chrysopidae) from the mid- Cretaceous amber of Myanmar
# 10.5281/zenodo.1206888
#
#
# Title: FIGURE1 in The first green lacewing (Insecta: Neuroptera: Chrysopidae) from the mid- Cretaceous amber of Myanmar
# 10.5281/zenodo.1206886
#
#
# Title: FIGURE 4. Phylogenetic tree for 6 in Madeirasquilla tuerkayi, a new genus and species of mantis shrimps from Madeira Island, eastern Atlantic (Crustacea: Stomatopoda: Nannosquillidae)
# 10.5281/zenodo.1206882
#
#
# Title: FIGURE 3 in Madeirasquilla tuerkayi, a new genus and species of mantis shrimps from Madeira Island, eastern Atlantic (Crustacea: Stomatopoda: Nannosquillidae)
# 10.5281/zenodo.1206880
#
#
# Title: FIGURE 1 in Madeirasquilla tuerkayi, a new genus and species of mantis shrimps from Madeira Island, eastern Atlantic (Crustacea: Stomatopoda: Nannosquillidae)
# 10.5281/zenodo.1206876
#
#
# Title: FIGURE 9 in Morphological examination and phylogenetic analysis clarify the taxonomic status of Cuban Longior Travassos & Kloss, 1958 (Nematoda: Thelastomatoidea: Hystrignathidae)
# 10.5281/zenodo.1206860
#
#
# Title: FIGURE 6 in Morphological examination and phylogenetic analysis clarify the taxonomic status of Cuban Longior Travassos & Kloss, 1958 (Nematoda: Thelastomatoidea: Hystrignathidae)
# 10.5281/zenodo.1206854
#
#
# Title: FIGURE 5 in Morphological examination and phylogenetic analysis clarify the taxonomic status of Cuban Longior Travassos & Kloss, 1958 (Nematoda: Thelastomatoidea: Hystrignathidae)
# 10.5281/zenodo.1206852
#
#
# Title: FIGURE 4 in Morphological examination and phylogenetic analysis clarify the taxonomic status of Cuban Longior Travassos & Kloss, 1958 (Nematoda: Thelastomatoidea: Hystrignathidae)
# 10.5281/zenodo.1206850
#
#
# Title: FIGURE 3 in Morphological examination and phylogenetic analysis clarify the taxonomic status of Cuban Longior Travassos & Kloss, 1958 (Nematoda: Thelastomatoidea: Hystrignathidae)
# 10.5281/zenodo.1206848
#
#
# Title: FIGURE 2 in Morphological examination and phylogenetic analysis clarify the taxonomic status of Cuban Longior Travassos & Kloss, 1958 (Nematoda: Thelastomatoidea: Hystrignathidae)
# 10.5281/zenodo.1206846
#
#
# Title: FIGURE 1 in Morphological examination and phylogenetic analysis clarify the taxonomic status of Cuban Longior Travassos & Kloss, 1958 (Nematoda: Thelastomatoidea: Hystrignathidae)
# 10.5281/zenodo.1206844
#
#
# Title: FIGURE 6 in Two new species of freshwater crayfish of the genus Faxonius (Decapoda: Cambaridae) from the Ozark Highlands of Arkansas and Missouri
# 10.5281/zenodo.1206832
#
#
# Title: FIGURE5 in Two new species of freshwater crayfish of the genus Faxonius (Decapoda: Cambaridae) from the Ozark Highlands of Arkansas and Missouri
# 10.5281/zenodo.1206830
#
#
# Title: FIGURE 3 in Two new species of freshwater crayfish of the genus Faxonius (Decapoda: Cambaridae) from the Ozark Highlands of Arkansas and Missouri
# 10.5281/zenodo.1206826
#
#
# Title: FIGURE 7 in New species of glass knifefish Eigenmannia loretana (Gymnotiformes: Sternopygidae) from the Western Amazon
# 10.5281/zenodo.1206762
#
#
# Title: FIGURE 4 in New species of glass knifefish Eigenmannia loretana (Gymnotiformes: Sternopygidae) from the Western Amazon
# 10.5281/zenodo.1206756
#
#
# Title: FIGURE 2 in New species of glass knifefish Eigenmannia loretana (Gymnotiformes: Sternopygidae) from the Western Amazon
# 10.5281/zenodo.1206752
#
#
# Title: FIGURE6 in New species of Chnoodes Chevrolat (Coleoptera: Coccinellidae) from French Guiana
# 10.5281/zenodo.1206744
#
#
# Title: FIGURE 1. Chnoodes centralis Sicard, 1912. A–D in New species of Chnoodes Chevrolat (Coleoptera: Coccinellidae) from French Guiana
# 10.5281/zenodo.1206734
#
#
# Title: FIGURE 13 in Copelatus Erichson from the Dominican Republic, with the description of a new species, comments on elytral striation and faunistic notes on Antillean species (Coleoptera: Dytiscidae: Copelatinae)
# 10.5281/zenodo.1206728
#
#
# Title: FIGURE 4. Hemilamprops chilensis n in Hemilamprops chilensis sp. nov. (Crustacea: Cumacea: Lampropidae) from the coast of Chile, with a key to the Chilean Lampropidae and remarks on the status of H. ultimaespei Zimmer, 1921 and H. lotusae Băcescu, 1969
# 10.5281/zenodo.1206718
#
#
# Title: FIGURE 2 in A new species of genus Eulimnadia Packard, 1874 (Branchiopoda: Spinicaudata: Limnadiidae) from India with an updated key for some Indian species
# 10.5281/zenodo.1206702
#
#
# Title: FIGURE 3 in A new species of Trachusa Panzer, 1804 (Megachilidae: Anthidiini) from southern Africa, with notes on the subgeneric classification and a key to the Afrotropical species
# 10.5281/zenodo.1206690
#
#
# Title: FIGURE 9 in Caridean prawn (Crustacea, Decapoda) from Dong'ao Island, Guangdong, China
# 10.5281/zenodo.1206682
#
#
# Title: FIGURE 4. Caridina zhujiangensis, new species. a in Caridean prawn (Crustacea, Decapoda) from Dong'ao Island, Guangdong, China
# 10.5281/zenodo.1206672
#
#
# Title: FIGURE2 in Caridean prawn (Crustacea, Decapoda) from Dong'ao Island, Guangdong, China
# 10.5281/zenodo.1206666
#
#
# Title: FIGURE 4 in Hypsibius vaskelae, a new species of Tardigrada (Eutardigrada, Hypsibiidae) from Russia
# 10.5281/zenodo.1206650
#
#
# Title: FIGURE 3. A–C in Hypsibius vaskelae, a new species of Tardigrada (Eutardigrada, Hypsibiidae) from Russia
# 10.5281/zenodo.1206648
#
#
# Title: FIGURE 2. A, C. Hypopygium, ventral. B. Maxillary palpus, dorsolateral. A in Phylogenetic position of Aerumnosa Mohrig (Diptera, Sciaridae) as revealed by multigene analysis, with the description of four new Oriental species
# 10.5281/zenodo.1206630
#
#
# Title: FIGURE 1. A. Wing, dorsal. B in Phylogenetic position of Aerumnosa Mohrig (Diptera, Sciaridae) as revealed by multigene analysis, with the description of four new Oriental species
# 10.5281/zenodo.1206628
#
#
# Title: FIGURE 5 in Cyrtodactylus tahuna sp. nov., a new bent-toed gecko (Reptilia: Squamata: Gekkonidae) from Sangihe Island, North Sulawesi, Indonesia
# 10.5281/zenodo.1206624
#
#
# Title: FIGURE 5 in The tenth member of stout newt (Amphibia: Salamandridae: Pachytriton): Description of a new species from Guangdong, southern China
# 10.5281/zenodo.1206606
#
#
# Title: FIGURE 3 in The tenth member of stout newt (Amphibia: Salamandridae: Pachytriton): Description of a new species from Guangdong, southern China
# 10.5281/zenodo.1206602
#
#
# Title: FIGURE 4 in A systematic study of the genus Atlanticus Scudder, 1894 from Zhejiang, China (Orthoptera: Tettigoniidae: Tettigoniinae)
# 10.5281/zenodo.1206584
#
#
# Title: FIGURE 2. A–C in A new species of Eburia Lacordaire, 1830 (Coleoptera: Cerambycidae) from Mexico
# 10.5281/zenodo.1206566
#
#
# Title: FIGURE 1. A–B in A new species of Eburia Lacordaire, 1830 (Coleoptera: Cerambycidae) from Mexico
# 10.5281/zenodo.1206564
#
#
# Title: FIGURES 8–13 in Taxonomic notes on Exetastes fukuchiyamanus Uchida, 1928 (Hymenoptera, Ichneumonidae, Banchinae), with description of a new species from Japan and China
# 10.5281/zenodo.1206558
#
#
# Title: FIGURES 1–7 in Taxonomic notes on Exetastes fukuchiyamanus Uchida, 1928 (Hymenoptera, Ichneumonidae, Banchinae), with description of a new species from Japan and China
# 10.5281/zenodo.1206556
#
#
# Title: FIGURES 9–11 in The genus Anarsia Meyrick (Lepidoptera, Gelechiidae) in Laos, with description of a new species and ten new records of the genus
# 10.5281/zenodo.1206550
#
#
# Title: FIGURES 7–8. Anarsia decora Li in The genus Anarsia Meyrick (Lepidoptera, Gelechiidae) in Laos, with description of a new species and ten new records of the genus
# 10.5281/zenodo.1206548
#
#
# Title: FIGURE 8 in Taxonomic review of the rare Mexican snake genus Chersodromus (Serpentes: Dipsadidae), with the description of two new species
# 10.5281/zenodo.1206538
#
#
# Title: FIGURE 4 in Taxonomic review of the rare Mexican snake genus Chersodromus (Serpentes: Dipsadidae), with the description of two new species
# 10.5281/zenodo.1206530
#
#
# Title: FIGURE 2 in Taxonomic review of the rare Mexican snake genus Chersodromus (Serpentes: Dipsadidae), with the description of two new species
# 10.5281/zenodo.1206526
#
#
# Title: FIGURE 13 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206520
#
#
# Title: FIGURE 11 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206516
#
#
# Title: FIGURE 9 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206512
#
#
# Title: FIGURE 7 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206508
#
#
# Title: FIGURE6 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206506
#
#
# Title: FIGURE 5 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206504
#
#
# Title: FIGURE 4 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206502
#
#
# Title: FIGURE3 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206500
#
#
# Title: FIGURE2 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206498
#
#
# Title: FIGURE 1 in Three new species of Tridentella Richardson, 1905 (Isopoda: Cymothoida: Tridentellidae) from New Caledonia
# 10.5281/zenodo.1206496
#
#
# Title: FIGURE 5 in New records of mosquitoes (Diptera: Culicidae) found in phytotelmata in Northern Argentina
# 10.5281/zenodo.1206492
#
#
# Title: FIGURE 2 in New records of mosquitoes (Diptera: Culicidae) found in phytotelmata in Northern Argentina
# 10.5281/zenodo.1206486
#
#
# Title: FIGURES 7–11 in A new species of Clidicus with asymmetrical parameres (Coleoptera, Staphylinidae, Scydmaeninae)
# 10.5281/zenodo.1206432
#
#
# Title: FIGURE 1. Fergusobia janetae n in Nematodes from galls on Myrtaceae. XI. Descriptions of five new species of Fergusobia from Australia
# 10.5281/zenodo.1206408
# [{'bucket': 'b645a5fb-e996-42a3-aaf5-a3f7ce75e853', 'checksum': 'md5:89a9f58721a73523c1ae855025b81ad4', 'key': 'oo_32747.jpg', 'links': {'self': 'https://zenodo.org/api/files/b645a5fb-e996-42a3-aaf5-a3f7ce75e853/oo_32747.jpg'}, 'size': 1085074, 'type': 'jpg'}]

# %% [markdown]
# # Ejercicio

# %% [markdown]
# * 1: Busca al menos dos repositorios digitales compatibles con OAI-PMH
# * 2: Utiliza los verbos del protocolo para encontrar los recursos de un tema en concreto (puedes filtrar por la descripción o en las palabras clave).
# * 3: Obtén un listado de los títulos, identificadores (DOI o cualquier otro) y la dirección del recurso.
# * 4: ¿Qué problemas has encontrado? ¿Has tenido que manejar más de un formato de metadatos? ¿Qué limitaciones tiene el protocolo OAI-PMH? ¿Cómo lo mejorarías?
# * 5: A través de los distintos métodos vistos (Uso de PID/DOI, OAI-PMH o APIs concretas de repositorios) intenta llegar al fichero de un dataset para mostrarlo (gráfica, imagen...).

# %% [markdown]
# #### 1. Busca al menos dos repositorios digitales compatibles con OAI-PMH

# %% [markdown]
# Utilizaremos los siguientes repositorios:
# * Zenodo. URL = https://zenodo.org/oai2d
# * UCM (Universidad Complutense de Madrid). URL = https://eprints.ucm.es/cgi/oai2

# %%
url1 = "https://zenodo.org/oai2d"
url2 = "https://eprints.ucm.es/cgi/oai2"

# %% [markdown]
# #### 2. Utiliza los verbos del protocolo para encontrar los recursos de un tema en concreto (puedes filtrar por la descripción o en las palabras clave)

# %%
### Zenodo ###
action = '?verb=ListRecords'
params =  '&metadataPrefix=oai_dc'
oai = requests.get(url1 + action + params) 
xmlTree = ET.fromstring(oai.text)
dc = xmlTree.findall('.//{http://www.openarchives.org/OAI/2.0/oai_dc/}dc')

# Buscamos el identificador del recurso seleccionado, que encontramos a través de la descripción.
count = True
flag = False
for elem in dc:
    for e in elem:
        keyword = 'Engyprosopon parvipectorale'
        if e.tag == '{http://purl.org/dc/elements/1.1/}identifier' and count == False:
            oaiID1 = e.text
            flag = True
        if e.tag == '{http://purl.org/dc/elements/1.1/}description' and keyword in e.text:
            count = False
        if flag == True:
            break
oaiID1
# Out:
# 'https://zenodo.org/record/1227825'

# %% [markdown]
# Para Zenodo, obtenemos el identificador de un único recurso que coincide con el tema especificado en la variable `keyword`.

# %%
### UCM ###
action = '?verb=ListRecords'
params =  '&metadataPrefix=oai_dc'
oai = requests.get(url2 + action + params) 
xmlTree = ET.fromstring(oai.text)
dc = xmlTree.findall('.//{http://www.openarchives.org/OAI/2.0/oai_dc/}dc')

# Buscamos el identificador del recurso seleccionado, que encontramos a través de la descripción.
count = True
flag = False
for elem in dc:
    for e in elem:
        keyword = 'Madrid'
        if e.tag == '{http://purl.org/dc/elements/1.1/}identifier' and count == False:
            oaiID2 = e.text
            flag = True
        if e.tag == '{http://purl.org/dc/elements/1.1/}description' and keyword in e.text:
            count = False
        if flag == True:
            break
oaiID2
# Out:
# 'https://eprints.ucm.es/id/eprint/1453/1/pon_4.pdf'

# %% [markdown]
# Nuevamente nos quedamos con un único recurso que tenga relación con la `keyword`, que es diferente en este caso.

# %% [markdown]
# #### 3. Obtén un listado de los títulos, identificadores (DOI o cualquier otro) y la dirección del recurso

# %%
### Zenodo ###
action = '?verb=GetRecord'
params =  '&metadataPrefix=oai_dc'
# Tomamos el identificador obtenido en la pregunta anterior
identifier = 'oai:zenodo.org:1227825'
l=[params, identifier]
params = "&identifier=".join(l)

oai = requests.get(url1 + action + params)
xmlTree = ET.fromstring(oai.text)

titles = xmlTree.findall('.//{http://purl.org/dc/elements/1.1/}title')
identifiers = xmlTree.findall('.//{http://purl.org/dc/elements/1.1/}identifier')

for elem in titles:
    print(elem.tag, elem.text)
    
for elem in identifiers:
    print(elem.tag, elem.text)
# Out:
# {http://purl.org/dc/elements/1.1/}title FIGURE 17 in Review of the genus Engyprosopon Günther, 1862 (Pleuronectiformes: Bothidae) from waters off Taiwan, with descriptions of two new species
# {http://purl.org/dc/elements/1.1/}identifier https://zenodo.org/record/1227825
# {http://purl.org/dc/elements/1.1/}identifier 10.5281/zenodo.1227825
# {http://purl.org/dc/elements/1.1/}identifier oai:zenodo.org:1227825

# %% [markdown]
# Como se puede apreciar, uno de los propios identificadores es la dirección url del recurso.

# %%
### UCM ###
action = '?verb=GetRecord'
params =  '&metadataPrefix=oai_dc'
# Tomamos el identificador obtenido en la pregunta anterior
identifier = 'oai:www.ucm.es:1453'
l=[params, identifier]
params = "&identifier=".join(l)

oai = requests.get(url2 + action + params)
xmlTree = ET.fromstring(oai.text)

titles = xmlTree.findall('.//{http://purl.org/dc/elements/1.1/}title')
identifiers = xmlTree.findall('.//{http://purl.org/dc/elements/1.1/}identifier')

for elem in titles:
    print(elem.tag, elem.text)
    
for elem in identifiers:
    print(elem.tag, elem.text)
# Out:
# {http://purl.org/dc/elements/1.1/}title La aplicación de los tributos en la ley general tributaria
# {http://purl.org/dc/elements/1.1/}identifier https://eprints.ucm.es/id/eprint/1453/1/pon_4.pdf

# %% [markdown]
# Nuevamente, el identificador (en este caso, único) es también la dirección url del recurso.

# %% [markdown]
# #### 4. ¿Qué problemas has encontrado? ¿Has tenido que manejar más de un formato de metadatos? ¿Qué limitaciones tiene el protocolo OAI-PMH? ¿Cómo lo mejorarías?

# %% [markdown]
# Durante la realización de las preguntas **2 y 3** he encontrado las siguientes complicaciones:
# * Ambos repositorios tienen un tamaño considerable, por lo que para encontrar recursos sobre un tema concreto ha sido necesario realizar una primera búsqueda a mano, comprobando qué metadatos presentan descripción, subjects, etc...
# * Para ambos casos el campo *description*, en el que basamos nuestra búsqueda de recursos concretos, se encuentra antes del campo *identifier*. Debido a las complicaciones presentes en XML para acceder a niveles concretos de los metadatos, ya que únicamente permite una lectura secuencial, ha sido necesaria la definición del flag `count` para asegurar que efectivamente estamos seleccionando el identificador correspondiente a la descripción deseada. Por otra parte, el funcionamiento de Python no permite que dentro de un `if` se ejecute una instrucción y después hacer usar `break`, sino que este último tiene que estar presente como argumento único de un bloque condicional. Por ello, se define también el flag `flag`. Probablemente no sea la solución más elegante, pero es suficiente.
# * Cuando hay varios identifiers para un mismo recurso, como es el caso del primer repositorio, tal y como se ha escrito el código siempre nos quedamos con el primero de todos los identificadores. En este caso, resulta ser id1:https://zenodo.org/record/1227825, la dirección url donde se encuentra el recurso. Sin embargo, uno de los identificadores es id2:oai:zenodo.org:1227825, que permitiría una implementación más automatizada para la pregunta 3. Este hecho no supone realmente un problema ya que una vez conocido el identificador podemos meterlo a mano, aunque de la otra manera podríamos implementarlo con código realizando el `join()` con las variables `oaiID1` y `oaiID2`.

# %% [markdown]
# #### 5. A través de los distintos métodos vistos (Uso de PID/DOI, OAI-PMH o APIs concretas de repositorios) intenta llegar al fichero de un dataset para mostrarlo (gráfica, imagen...)

# %%
download_url = "https://zenodo.org/record/1227825/files/figure.png?download=1"
r = requests.get(download_url)
file = open("Zenodo_image.png", "wb")
file.write(r.content)
file.close()

# %% [markdown]
# Lo que se hace en esta celda de código es:
# * Acceder al recurso utilizando el identificador previamente obtenido
# * Añadir `/files/figure.png=download=1` para descargar el archivo
# * Realizar un request con `request.get`
# * Escribir los contenidos en un fichero `.png`
